# %% [markdown]
# # Ground Truth from Stand-Up Comedy Transcripts

# %% [markdown]
# ### 1. Seperate the transcript into individual sentences and map the timestamps of the audio with the sentences

# %% [markdown]
# Forced Alignment was done via the aid of Aeneas

# %% [markdown]
# ### 2. Use Laughter Detection Tool to find the laughter in the given audio

# %% [markdown]
# Laughter Detection is Done via
#
# https://colab.research.google.com/drive/1ixYPfET1HXgxr2K1SjgYY11-BKu7u_UZ?usp=sharing&pli=1&authuser=2#scrollTo=R3LqFPm9biYP
#
# https://colab.research.google.com/drive/1ixYPfET1HXgxr2K1SjgYY11-BKu7u_UZ#scrollTo=R3LqFPm9biYP

# %% [markdown]
# ### 3. Match the funny sentences with the laughter

# %%
import json

# %%
dg_laugh_times = {
    'laugh_0': {'start': 17.268, 'end': 19.352},
    'laugh_1': {'start': 32.292, 'end': 34.182},
    'laugh_2': {'start': 38.790, 'end': 41.441},
    'laugh_3': {'start': 44.903, 'end': 53.441},
    'laugh_4': {'start': 68.880, 'end': 73.824},
    'laugh_5': {'start': 90.491, 'end': 94.607},
    'laugh_6': {'start': 107.842, 'end': 110.958},
    'laugh_7': {'start': 125.042, 'end': 128.508},
}

# %%
def create_laughter_map(laugh_times, transcript_data_path):
    with open(transcript_data_path, 'r') as file:
        transcript_data = json.load(file)

    laughter_map = {}
    used_sentences = set()
    i = 1

    for laugh_info in laugh_times.values():
        funny_sent = []
        laugh_start = laugh_info['start']
        laugh_end = laugh_info['end']
        for fragment in transcript_data["fragments"]:
            start_frag = float(fragment['begin'])
            end_frag = float(fragment['end'])
            if end_frag <= laugh_start:
                sentences = " ".join(fragment['lines']).strip()
                if sentences and sentences not in used_sentences:
                    funny_sent.append(sentences)
                    used_sentences.add(sentences)
                if len(funny_sent) > 2:
                    funny_sent.pop(0)
        funny_sent_comb = " ".join(funny_sent)
        if funny_sent_comb:
            laughter_map[f"laugh {i}"] = [laugh_start, laugh_end, funny_sent_comb]
            i += 1

    return laughter_map

# %%
import json

def create_laughter_map(laugh_times, transcript_data_path):
    with open(transcript_data_path, 'r') as file:
        transcript_data = json.load(file)

    laughter_map = {}
    used_sentences = set()
    i = 1

    for laugh_info in laugh_times.values():
        funny_sent = []
        laugh_start = laugh_info['start']
        laugh_end = laugh_info['end']
        for fragment in transcript_data["fragments"]:
            start_frag = float(fragment['begin'])
            end_frag = float(fragment['end'])
            
            if start_frag <= laugh_start and end_frag >= laugh_start:
                sentences = " ".join(fragment['lines']).strip()
                if sentences and sentences not in used_sentences:
                    funny_sent.append(sentences)
                    used_sentences.add(sentences)
                break  

            if end_frag < laugh_start and start_frag < laugh_start:
                sentences = " ".join(fragment['lines']).strip()
                if sentences and sentences not in used_sentences:
                    funny_sent.append(sentences)
                    used_sentences.add(sentences)
                if len(funny_sent) > 1:
                    funny_sent.pop(0)

        funny_sent_comb = " ".join(funny_sent)
        if funny_sent_comb:
            laughter_map[f"laugh {i}"] = [laugh_start, laugh_end, funny_sent_comb]
            i += 1

    return laughter_map

# %%
dg_laughter_map = create_laughter_map(dg_laugh_times, "/home/ada/humor/data/stand_up_dataset/dg/dg_output.json")

for laugh_num, info in dg_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()
# Out:
# laugh 1
# Start Time: 17.268
# End Time: 19.352
# Funny Sentences: Just tears, he was giving me this mean mug, he was like... I was like, what the fuck is wrong with this kid?
#
# laugh 2
# Start Time: 32.292
# End Time: 34.182
# Funny Sentences: The sweetest thing he was allowed was mints. He was just allowed to have mints.
#
# laugh 3
# Start Time: 38.79
# End Time: 41.441
# Funny Sentences: So he would steal mints by the handful. So his breath was so fresh... the vapors from his own mouth made his eyes water.
#
# laugh 4
# Start Time: 44.903
# End Time: 53.441
# Funny Sentences: Like, he'd be like, "Hello!"
#
# laugh 5
# Start Time: 68.88
# End Time: 73.824
# Funny Sentences: You know, they were cool. You know, we'd trade jerk- chicken recipes and stuff.
#
# laugh 6
# Start Time: 90.491
# End Time: 94.607
# Funny Sentences: And he... he was just a mean-spirited kid, like, he kind Of... Like, he watched HBO just a little too early and was just kind of a mean kid in general, so he would just come through and just...He wanted to get to his slide, so he just pushed over this little girl, she fell over, and her Trinidadian babysitter comes over and goes, "Hey!
#
# laugh 7
# Start Time: 107.842
# End Time: 110.958
# Funny Sentences: And she goes, "Don't you talk to me like that, I am a grown-up, you will respect me." And he goes, "Suck my d!ck!"
#
# laugh 8
# Start Time: 125.042
# End Time: 128.508
# Funny Sentences: I shit you not... The lady goes, "Someone betta get this little niglet away from me."

# %%
dg_funny_sentences = []
for value in dg_laughter_map.values():
  dg_funny_sentences.append(value[2])

for sentences in dg_funny_sentences:
  print(sentences, "\n")
# Out:
# Just tears, he was giving me this mean mug, he was like... I was like, what the fuck is wrong with this kid?
#
# The sweetest thing he was allowed was mints. He was just allowed to have mints.
#
# So he would steal mints by the handful. So his breath was so fresh... the vapors from his own mouth made his eyes water.
#
# Like, he'd be like, "Hello!"
#
# You know, they were cool. You know, we'd trade jerk- chicken recipes and stuff.
#
# And he... he was just a mean-spirited kid, like, he kind Of... Like, he watched HBO just a little too early and was just kind of a mean kid in general, so he would just come through and just...He wanted to get to his slide, so he just pushed over this little girl, she fell over, and her Trinidadian babysitter comes over and goes, "Hey!
#
# And she goes, "Don't you talk to me like that, I am a grown-up, you will respect me." And he goes, "Suck my d!ck!"
#
# I shit you not... The lady goes, "Someone betta get this little niglet away from me."

# %%
def make_sent_list(laughter_map):
  sentences = []
  for value in laughter_map.values():
    sentences.append(value[2])
  return sentences

# %% [markdown]
# ### 3. Amplitude graph

# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in /home/ada/humor/.venv/lib/python3.8/site-packages (0.10.2.post1)
# Requirement already satisfied: audioread>=2.1.9 in /home/ada/humor/.venv/lib/python3.8/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /home/ada/humor/.venv/lib/python3.8/site-packages (from librosa) (1.24.4)
# Requirement already satisfied: scipy>=1.2.0 in /home/ada/humor/.venv/lib/python3.8/site-packages (from librosa) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/ada/humor/.venv/lib/python3.8/site-packages (from librosa) (1.0.2)
# Requirement already satisfied: joblib>=0.14 in /home/ada/humor/.venv/lib/python3.8/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /home/ada/humor/.venv/lib/python3.8/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /home/ada/humor/.venv/lib/python3.8/site-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /home/ada/humor/.venv/lib/python3.8/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /home/ada/humor/.venv/lib/python3.8/site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /home/ada/humor/.venv/lib/python3.8/site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/ada/humor/.venv/lib/python3.8/site-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /home/ada/humor/.venv/lib/python3.8/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /home/ada/humor/.venv/lib/python3.8/site-packages (from librosa) (1.0.8)
# Requirement already satisfied: packaging in /home/ada/humor/.venv/lib/python3.8/site-packages (from lazy-loader>=0.1->librosa) (24.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /home/ada/humor/.venv/lib/python3.8/site-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: importlib-metadata in /home/ada/humor/.venv/lib/python3.8/site-packages (from numba>=0.51.0->librosa) (7.1.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/ada/humor/.venv/lib/python3.8/site-packages (from pooch>=1.1->librosa) (4.2.2)
# Requirement already satisfied: requests>=2.19.0 in /home/ada/humor/.venv/lib/python3.8/site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ada/humor/.venv/lib/python3.8/site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /home/ada/humor/.venv/lib/python3.8/site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /home/ada/humor/.venv/lib/python3.8/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ada/humor/.venv/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ada/humor/.venv/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ada/humor/.venv/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ada/humor/.venv/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.6.2)
# Requirement already satisfied: zipp>=0.5 in /home/ada/humor/.venv/lib/python3.8/site-packages (from importlib-metadata->numba>=0.51.0->librosa) (3.19.2)
#
# [notice] A new release of pip is available: 24.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_mp3(audio_file, name):
    data, sr = librosa.load(audio_file, sr=None)
    time = np.arange(len(data)) / sr
    plt.figure(figsize=(14, 5))
    plt.plot(time, data, color='pink')
    plt.title(f"Waveform of {name}")
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.show()

# %%
dg_audio = "/home/ada/humor/data/stand_up_dataset/dg/DG_W_audio_11.mp3"

# %%
plot_mp3(dg_audio, "Donald Glover")

# %%
def plot_mp3_laugh_start(audio, name, laughter_map):
    data, sr = librosa.load(audio, sr=None)
    time = np.arange(len(data)) / sr
    plt.figure(figsize=(14, 5))
    plt.plot(time, data, color="pink")
    for info in laughter_map.values():
        plt.axvline(x=info[0], color='blue', linestyle='--', linewidth=1)
        plt.axvline(x=info[1], color='red', linestyle='--', linewidth=1)

    plt.title(f"Waveform of {name} Transcript")
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.show()

# %%
plot_mp3_laugh_start(dg_audio, "Donald Glover", dg_laughter_map)

# %%
def split_sentence(sentence, max_length=80):
    lines = []
    while len(sentence) > max_length:
        split_index = sentence.rfind(' ', 0, max_length)
        if split_index == -1:

            split_index = max_length
        lines.append(sentence[:split_index].strip())
        sentence = sentence[split_index:].strip()
    lines.append(sentence)
    return lines

def plot_mp3_laugh_sent(audio, name, laughter_map, sentences):
    data, sr = librosa.load(audio, sr=None)
    time = np.arange(len(data)) / sr
    plt.figure(figsize=(14, 5))
    plt.plot(time, data, color="pink")

    for info in laughter_map.values():
        start = info[0]
        end = info[1]
        sentence = info[2]
        if start != list(laughter_map.keys())[-1]:
            lines = split_sentence(sentence)
            label_text = '\n'.join(lines)
            plt.text(start, np.min(data) - 0.1 * (np.max(data) - np.min(data)), label_text, rotation=90, verticalalignment='top', horizontalalignment='center', fontsize=8)
        else:
            plt.text(start, np.min(data) - 0.1 * (np.max(data) - np.min(data)), sentence, rotation=90, verticalalignment='top', horizontalalignment='center', fontsize=8)

        plt.axvline(x=start, color='blue', linestyle='--', linewidth=1)
        plt.axvline(x=end, color='green', linestyle=':', linewidth=1)

    plt.title(f"Waveform of {name} Transcript")
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.show()

# %%
plot_mp3_laugh_sent(dg_audio, "Donald Glover", dg_laughter_map, sentences)

# %% [markdown]
# ## Anthony Jeselnik

# %%
aj_laugh_times = {
    "laugh_1": {'start': 16.898, 'end': 19.405},
    "laugh_2": {'start': 29.085, 'end': 31.100},
    "laugh_3": {'start': 34.874, 'end': 36.233},
    "laugh_4": {'start': 43.756, 'end': 48.912},
    "laugh_5": {'start': 86.505, 'end': 88.497},
    "laugh_6": {'start': 93.982, 'end': 100.708},
    "laugh_7": {'start': 114.653, 'end': 120.278}
}

# %%
aj_laughter_map = create_laughter_map(aj_laugh_times, "/home/ada/humor/data/stand_up_dataset/aj/aj_output.json")

for laugh_num, info in aj_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()
# Out:
# laugh 1
# Start Time: 16.898
# End Time: 19.405
# Funny Sentences: When I was a kid, we were poor. So poor I remember, just so I could go to my senior prom, just so I could go to my senior prom, I had to sell my U.S. passport on the street.
#
# laugh 2
# Start Time: 29.085
# End Time: 31.1
# Funny Sentences: Of course this was before 9/11 so... my bad, everybody. Weird joke to clap for, but sure.
#
# laugh 3
# Start Time: 34.874
# End Time: 36.233
# Funny Sentences: My mom actually should've been on one of the planes that crashed on 9/11.
#
# laugh 4
# Start Time: 43.756
# End Time: 48.912
# Funny Sentences: I think.I mean, don't get me wrong, I loved my mother.
#
# laugh 5
# Start Time: 86.505
# End Time: 88.497
# Funny Sentences: She'd pull me aside and say, "Anthony, who's your new friend? Is he a drug dealer?"
#
# laugh 6
# Start Time: 93.982
# End Time: 100.708
# Funny Sentences: Put your money away. "I never get to see my family anymore, really.
#
# laugh 7
# Start Time: 114.653
# End Time: 120.278
# Funny Sentences: 'Cause they're all in jail for the exact same thing. My testimony.

# %%
aj_sentences = make_sent_list(aj_laughter_map)
print(aj_sentences)
# Out:
# ['When I was a kid, we were poor. So poor I remember, just so I could go to my senior prom, just so I could go to my senior prom, I had to sell my U.S. passport on the street.', 'Of course this was before 9/11 so... my bad, everybody. Weird joke to clap for, but sure.', "My mom actually should've been on one of the planes that crashed on 9/11.", "I think.I mean, don't get me wrong, I loved my mother.", 'She\'d pull me aside and say, "Anthony, who\'s your new friend? Is he a drug dealer?"', 'Put your money away. "I never get to see my family anymore, really.', "'Cause they're all in jail for the exact same thing. My testimony."]

# %%
aj_audio = "/home/ada/humor/data/stand_up_dataset/aj/AJ_TP_audio_15.mp3"

# %%
plot_mp3_laugh_sent(aj_audio, "Anthony Jeselnik", aj_laughter_map, aj_sentences)

# %% [markdown]
# Chelsea Peretti: One of the Greats

# %%
cp_laugh_times = {
    "laugh_1": {'start': 13.212, 'end': 18.877},
    "laugh_2": {'start': 24.966, 'end': 28.352},
    "laugh_3": {'start': 29.574, 'end': 32.654},
    "laugh_4": {'start': 59.008, 'end': 67.306},
    "laugh_5": {'start': 69.093, 'end': 72.455},
    "laugh_6": {'start': 74.383, 'end': 88.488}
}

# %%
cp_laughter_map = create_laughter_map(cp_laugh_times, "/home/ada/humor/data/stand_up_dataset/cp/cp_output.json")

for laugh_num, info in cp_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()
# Out:
# laugh 1
# Start Time: 13.212
# End Time: 18.877
# Funny Sentences: I'm not exaggerating. It's like that wedding portraiture, where it's just like, two assholes back to back in the woods, just like... [laughing shrilly] "To the future!"
#
# laugh 2
# Start Time: 24.966
# End Time: 28.352
# Funny Sentences: I'm just like, "Next, next, next, next, more, more, more, more." Every photo, they were just like... [giggles shrilly] "Uh-oh, it's us again."
#
# laugh 3
# Start Time: 59.008
# End Time: 67.306
# Funny Sentences: She calls him her "hubby," which, to me is on par with the "N" word. Like let's... Let's eradicate both.
#
# laugh 4
# Start Time: 69.093
# End Time: 72.455
# Funny Sentences: My hubby is sleeping. He breathed in, he breathed out.
#
# laugh 5
# Start Time: 74.383
# End Time: 88.488
# Funny Sentences: He breathed in, he breathed out." I just keep waiting for the day where she is like, "My hubby shot himself in the face!

# %%
cp_sentences = make_sent_list(cp_laughter_map)
print(cp_sentences)
# Out:
# ['I\'m not exaggerating. It\'s like that wedding portraiture, where it\'s just like, two assholes back to back in the woods, just like... [laughing shrilly] "To the future!"', 'I\'m just like, "Next, next, next, next, more, more, more, more." Every photo, they were just like... [giggles shrilly] "Uh-oh, it\'s us again."', 'She calls him her "hubby," which, to me is on par with the "N" word. Like let\'s... Let\'s eradicate both.', 'My hubby is sleeping. He breathed in, he breathed out.', 'He breathed in, he breathed out." I just keep waiting for the day where she is like, "My hubby shot himself in the face!']

# %%
cp_audio = "/home/ada/humor/data/stand_up_dataset/cp/CP_OTG_audio_18.mp3"

# %%
plot_mp3_laugh_sent(cp_audio, "Chelsea Peretti", cp_laughter_map, cp_sentences)

# %% [markdown]
# Louis C.K

# %%
lck_laugh_times = {
    "laugh_1": {'start': 3.206, 'end': 4.668},
    "laugh_2": {'start': 17.375, 'end': 20.770},
    "laugh_3": {'start': 31.709, 'end': 41.446},
    "laugh_4": {'start': 45.124, 'end': 48.943},
    "laugh_5": {'start': 49.344, 'end': 55.403},
    "laugh_6": {'start': 57.949, 'end': 64.031},
    "laugh_7": {'start': 65.540, 'end': 67.379}
}

# %%
lck_laughter_map = create_laughter_map(lck_laugh_times, "/home/ada/humor/data/stand_up_dataset/lck/lck_output.json")

for laugh_num, info in lck_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()
# Out:
# laugh 1
# Start Time: 3.206
# End Time: 4.668
# Funny Sentences: I was talking to my friend the other day about Jesus... uh, Christ, and, um...
#
# laugh 2
# Start Time: 17.375
# End Time: 20.77
# Funny Sentences: And he said, "I don't think so." And I said, that's okay, it already all happened.
#
# laugh 3
# Start Time: 31.709
# End Time: 41.446
# Funny Sentences: Think about it." I'm like, "You fucking think about it, you idiot.
#
# laugh 4
# Start Time: 45.124
# End Time: 48.943
# Funny Sentences: Catholic? Okay, Jesus was Catholic and he had a gold chain with a cross.
#
# laugh 5
# Start Time: 49.344
# End Time: 55.403
# Funny Sentences: And when they nailed him up, he was like, "Oh, that's why we have those!"
#
# laugh 6
# Start Time: 57.949
# End Time: 64.031
# Funny Sentences: I didn't even know. Oh, fuck, that's me!
#
# laugh 7
# Start Time: 65.54
# End Time: 67.379
# Funny Sentences: I'm the little guy on it!"

# %%
lck_sentences = make_sent_list(lck_laughter_map)
print(lck_sentences)
# Out:
# ['I was talking to my friend the other day about Jesus... uh, Christ, and, um...', 'And he said, "I don\'t think so." And I said, that\'s okay, it already all happened.', 'Think about it." I\'m like, "You fucking think about it, you idiot.', 'Catholic? Okay, Jesus was Catholic and he had a gold chain with a cross.', 'And when they nailed him up, he was like, "Oh, that\'s why we have those!"', "I didn't even know. Oh, fuck, that's me!", 'I\'m the little guy on it!"']

# %%
lck_audio = "/home/ada/humor/data/stand_up_dataset/lck/LCK_SY_audio_06.mp3"

# %%
plot_mp3_laugh_sent(lck_audio, "Louis CK", lck_laughter_map, lck_sentences)

# %% [markdown]
# John Mulaney

# %%
jm_laugh_times = {
    "laugh_1": {'start': 1.968, 'end': 5.389},
    "laugh_1": {'start': 20.235, 'end': 22.628},
    "laugh_2": {'start': 30.546, 'end': 32.020},
    "laugh_3": {'start': 44.332, 'end': 46.485},
    "laugh_4": {'start': 59.492, 'end': 65.865},
    "laugh_5": {'start': 67.85, 'end': 70.762},
    "laugh_6": {'start': 73.527, 'end': 74.207},
    "laugh_7": {'start': 83.9075, 'end': 85.899},
    "laugh_8": {'start': 97.755, 'end': 105.980},
    "laugh_9": {'start': 113.782, 'end': 125.0765}
}

# %%
jm_laughter_map = create_laughter_map(jm_laugh_times, "/home/ada/humor/data/stand_up_dataset/jm/jm_output.json")

for laugh_num, info in jm_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()
# Out:
# laugh 1
# Start Time:
# ['We were moving apartments, we had a bunch of clothes and furniture, so we made a whole day out of it. We made these big piles of clothes, we put the piles into these big boxes, then we put the boxes into the back of my car, and then they stayed there for four months.', 'And I said, "Of course I did! On an unrelated note, I\'m going to walk out the front door right now."', 'I got a bunch of shirts! Take \'em away!"', 'How do I write that on my taxes? "Dear IRS, please deduct from my federal income tax one XXL Billabong T-shirt from youth.', 'Please deduct this from my 2017 income." That sleep shirt bullshit.', '"Well, if it\'s too big you can just wear it as a sleep shirt."', "No, I get that, Mom, but why don't we just tell our relatives that I'm a four-year-old boy and I don't wear a man's XXL T-shirt?", "Oh, I get it. So rather than violate these meaningless politeness rules, I'll just go to bed in a smock like goddamn Ebenezer Scrooge.", "Why don't you give me a candle for looking in the mirror and a floppy hat and I'll tremble off to bed in my long Victorian nightgown?"]

# %%
jm_audio = "/home/ada/humor/data/stand_up_dataset/jm/JM_KDRC_audio_12.mp3"

# %%
plot_mp3_laugh_sent(jm_audio, "John Mulaney", jm_laughter_map, jm_sentences)

# %% [markdown]
# # Other Transcripts

# %% [markdown]
# Anthony Jeselnik 2

# %%
aj2_laugh_times = {
    'laugh_1': {'start': 53.522, 'end': 57.255}, 
    'laugh_3': {'start': 78.781, 'end': 83.053}, 
    'laugh_4': {'start': 93.547, 'end': 96.904}, 
    }

# %%
aj2_laughter_map = create_laughter_map(aj2_laugh_times, "/home/ada/humor/data/stand_up_dataset/aj2/aj2_output.json")

for laugh_num, info in aj2_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()
# Out:
# laugh 1
# Start Time: 53.522
# End Time: 57.255
# Funny Sentences: And then I couldn't help myself. I said, "And I know my grandma loved it too, because it combined her two favorite things: spending time with her grandchildren, and using the 'N' word."
#
# laugh 2
# Start Time: 78.781
# End Time: 83.053
# Funny Sentences: Now I promise you... I promise you... until you've heard your grandfather gasp at his own wife's funeral... ...at a Methodist Church in Vicksburg, Mississippi... you are not a real comedian.
#
# laugh 3
# Start Time: 93.547
# End Time: 96.904
# Funny Sentences: I am a pure comedian. I think I'm one of the best comedians of all time.

# %%
aj2_sentences = make_sent_list(aj2_laughter_map)
print(aj2_sentences)
# Out:
# ['And then I couldn\'t help myself. I said, "And I know my grandma loved it too, because it combined her two favorite things: spending time with her grandchildren, and using the \'N\' word."', "Now I promise you... I promise you... until you've heard your grandfather gasp at his own wife's funeral... ...at a Methodist Church in Vicksburg, Mississippi... you are not a real comedian.", "I am a pure comedian. I think I'm one of the best comedians of all time."]

# %% [markdown]
# Ali Wong

# %%
aw_laugh_times = {
    'laugh_1': {'start': 21.007, 'end': 28.986}, 
    'laugh_2': {'start': 33.005, 'end': 37.756}, 
    'laugh_3': {'start': 48.803, 'end': 51.189}, 
    'laugh_4': {'start': 58.001, 'end': 69.002},  
    'laugh_5': {'start': 60.001, 'end': 61.762},    
    'laugh_6': {'start': 95.523, 'end': 98.684}, 
}

# %%
aw_laughter_map = create_laughter_map(aw_laugh_times, "/home/ada/humor/data/stand_up_dataset/aw/aw_output.json")

for laugh_num, info in aw_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()
# Out:
# laugh 1
# Start Time: 21.007
# End Time: 28.986
# Funny Sentences: It was so emotional. We were screaming and fighting and yelling and it all came to a climax when she refused to let go of a Texas Instruments TI-82... manual.
#
# laugh 2
# Start Time: 33.005
# End Time: 37.756
# Funny Sentences: The manual. She don't even know... where the calculator is.
#
# laugh 3
# Start Time: 48.803
# End Time: 51.189
# Funny Sentences: It cost like $200. And everybody thought it was like this Judy Jetson's laptop from the future.
#
# laugh 4
# Start Time: 58.001
# End Time: 69.002
# Funny Sentences: It could graph. It was like the Tesla of my time.
#
# laugh 5
# Start Time: 95.523
# End Time: 98.684
# Funny Sentences: "And I'm not trying to be a procrastinator anymore. Because according to Deepak-Oprah, that's not the way for me to achieve my optimum level of success."

# %%
aw_sentences = make_sent_list(aw_laughter_map)
print(aw_sentences)
# Out:
# ['It was so emotional. We were screaming and fighting and yelling and it all came to a climax when she refused to let go of a Texas Instruments TI-82... manual.', "The manual. She don't even know... where the calculator is.", "It cost like $200. And everybody thought it was like this Judy Jetson's laptop from the future.", 'It could graph. It was like the Tesla of my time.', '"And I\'m not trying to be a procrastinator anymore. Because according to Deepak-Oprah, that\'s not the way for me to achieve my optimum level of success."']

# %% [markdown]
# Ali Wong 2

# %%
aw2_laugh_times = {
    'laugh_1': {'start': 10.269, 'end': 12.379}, 
    'laugh_2': {'start': 40.632, 'end': 42.414}, 
    'laugh_3': {'start': 48.557, 'end': 50.081}, 
    'laugh_4': {'start': 63.2116, 'end': 65.0634}, 
    'laugh_5': {'start': 66.352, 'end': 68.18}, 
    'laugh_6': {'start': 92.823, 'end': 94.910}, 
    'laugh_7': {'start': 96.622, 'end': 98.919}, 
    'laugh_8': {'start': 117.020, 'end': 121.0765}
}

# %%
aw2_laughter_map = create_laughter_map(aw2_laugh_times, "/home/ada/humor/data/stand_up_dataset/aw2/aw2_output.json")

for laugh_num, info in aw2_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()
# Out:
# laugh 1
# Start Time: 10.269
# End Time: 12.379
# Funny Sentences: It's lonely. My mom is 80, going through a full blown mid-life crisis.
#
# laugh 2
# Start Time: 40.632
# End Time: 42.414
# Funny Sentences: She doesn't have any black friends. Life is not Rush Hour, the movie, OK?
#
# laugh 3
# Start Time: 48.557
# End Time: 50.081
# Funny Sentences: I need children to be there for me when I'm older, when I get as old as her.
#
# laugh 4
# Start Time: 63.2116
# End Time: 65.0634
# Funny Sentences: And when I say be there for me, I mean pay for me when my husband isn't around to support me anymore. I'm not trying to be one of those old Chinese ladies who recycles for a living.
#
# laugh 5
# Start Time: 66.352
# End Time: 68.18
# Funny Sentences: That's not my destiny, OK?
#
# laugh 6
# Start Time: 92.823
# End Time: 94.91
# Funny Sentences: They got no shame. They're like, "I'm just gonna recycle... go bald... go to the park, do this shit."
#
# laugh 7
# Start Time: 96.622
# End Time: 98.919
# Funny Sentences: They do that 'cause it's a free activity.
#
# laugh 8
# Start Time: 117.02
# End Time: 121.0765
# Funny Sentences: Their in a contest to see who's gonna burn out first. Old Asian ladies and the sun are like the Tupac and Biggie of longevity.

# %%
aw2_sentences = make_sent_list(aw2_laughter_map)
print(aw2_sentences)
# Out:
# ["It's lonely. My mom is 80, going through a full blown mid-life crisis.", "She doesn't have any black friends. Life is not Rush Hour, the movie, OK?", "I need children to be there for me when I'm older, when I get as old as her.", "And when I say be there for me, I mean pay for me when my husband isn't around to support me anymore. I'm not trying to be one of those old Chinese ladies who recycles for a living.", "That's not my destiny, OK?", 'They got no shame. They\'re like, "I\'m just gonna recycle... go bald... go to the park, do this shit."', "They do that 'cause it's a free activity.", "Their in a contest to see who's gonna burn out first. Old Asian ladies and the sun are like the Tupac and Biggie of longevity."]

# %% [markdown]
# Chelsea Peretti 2

# %%
cp2_laugh_times = {
    'laugh_1': {'start': 15.0134, 'end': 21.524}, 
    'laugh_2': {'start': 29.9807, 'end': 34.641}, 
    'laugh_3': {'start': 38.318, 'end': 41.503}, 
    'laugh_4': {'start': 52.301, 'end': 61.693}, 
    'laugh_5.wav': {'start': 64.152, 'end': 72.795}, 
    'laugh_6.wav': {'start': 78.393, 'end': 99.004}, 
    'laugh_7.wav': {'start': 102.916, 'end': 107.811}, 
    'laugh_8.wav': {'start': 111.441, 'end': 113.994}, 
    'laugh_9.wav': {'start': 116.758, 'end': 128.516}, 
    'laugh_10.wav': {'start': 130.6942, 'end': 132.076}
}

cp2_laughter_map = create_laughter_map(cp2_laugh_times, "/home/ada/humor/data/stand_up_dataset/cp2/cp2_output.json")

for laugh_num, info in cp2_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

cp2_sentences = make_sent_list(cp2_laughter_map)
# Out:
# laugh 1
# Start Time: 15.0134
# End Time: 21.524
# Funny Sentences: Go onto her comments and just be like, "People say I look just like you." She'll be like, "No!"
#
# laugh 2
# Start Time: 29.9807
# End Time: 34.641
# Funny Sentences: It's not to make them look youthful, you know. "Hi, everyone, same old me."
#
# laugh 3
# Start Time: 38.318
# End Time: 41.503
# Funny Sentences: It's actually to stop them from sweating, because why would you, you know, as a human?
#
# laugh 4
# Start Time: 52.301
# End Time: 61.693
# Funny Sentences: I did stop sweating out of my armpits, but I started sweating out of my butthole." So, I'm... uh... Is that a good trade?
#
# laugh 5
# Start Time: 64.152
# End Time: 72.795
# Funny Sentences: like, kind of a deal with the devil. Then I'm imagining the guy that sees her out somewhere and is just like... "Oh, ho, ho, ho."
#
# laugh 6
# Start Time: 78.393
# End Time: 99.004
# Funny Sentences: He's like... [constricted laughter] He's like, [surfer voice] "She is so fucking hot. Her armpits are bone-fucking-dry... just like I always dreamed of."
#
# laugh 7
# Start Time: 102.916
# End Time: 107.811
# Funny Sentences: This is a whole new kind of juicy booty." [audience cheers and applauds] He's a surfer.
#
# laugh 8
# Start Time: 111.441
# End Time: 113.994
# Funny Sentences: That's his profession. Why just because you go onto the ocean on a thingy... do you have a dialect?
#
# laugh 9
# Start Time: 116.758
# End Time: 128.516
# Funny Sentences: Why just 'cause you have an athletic skill set, do you laugh like... [constricted laughter] It's like, "Just stop making such a tight circle with your mouth... and then more laugh sounds could get out."

# %% [markdown]
# Donald Glover 2

# %%
dg2_laugh_times = {
    'laugh_1': {'start': 20.288, 'end': 26.293}, 
    'laugh_2': {'start': 28.803, 'end': 35.910}, 
    'laugh_3': {'start': 40.953, 'end': 43.275}, 
    'laugh_4': {'start': 45.151, 'end': 46.488}, 
    'laugh_5': {'start': 49.068, 'end': 51.297}, 
    'laugh_6': {'start': 56.246, 'end': 71.937}, 
    'laugh_7': {'start': 77.121, 'end': 84.510}, 
    'laugh_8': {'start': 92.086, 'end': 93.329}, 
    'laugh_9': {'start': 96.542, 'end': 97.152}, 
    'laugh_10': {'start': 98.559, 'end': 104.658}, 
    'laugh_11': {'start': 108.207, 'end': 110.076}
}

dg2_laughter_map = create_laughter_map(dg2_laugh_times, "/home/ada/humor/data/stand_up_dataset/dg2/dg2_output.json")

for laugh_num, info in dg2_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

dg2_sentences = make_sent_list(dg2_laughter_map)
# Out:
# laugh 1
# Start Time: 20.288
# End Time: 26.293
# Funny Sentences: I can't believe this happened so close to us." And she goes, "Yeah, well, "if anybody ever tries to rape me, I'm just gonna shit on 'em."
#
# laugh 2
# Start Time: 40.953
# End Time: 43.275
# Funny Sentences: I have no problem." Uh... Two things, lady.
#
# laugh 3
# Start Time: 45.151
# End Time: 46.488
# Funny Sentences: Number one, he's a rapist.
#
# laugh 4
# Start Time: 49.068
# End Time: 51.297
# Funny Sentences: So his tolerance for gross stuff is probably pretty high.
#
# laugh 5
# Start Time: 56.246
# End Time: 71.937
# Funny Sentences: Number two... you can shit on command? Like, you can just... You can just poop whenever you want to?
#
# laugh 6
# Start Time: 77.121
# End Time: 84.51
# Funny Sentences: No, I can't poop whenever I want. Somebody can run down... down the stage right now and pull out a gun and be like, "Shit yourself!
#
# laugh 7
# Start Time: 92.086
# End Time: 93.329
# Funny Sentences: I'd be like, "Blow my head off." I can't do it, I can't do it, I'm not... Me and my butt are, like, always on the third date, I feel like.
#
# laugh 8
# Start Time: 96.542
# End Time: 97.152
# Funny Sentences: I feel like, me, I'm always like, come on, let's... hurry up, let's do this. And my butt's always like, stop rushing me, when the time is right.
#
# laugh 9
# Start Time: 108.207
# End Time: 110.076
# Funny Sentences: I'm not in love yet. That was me in a domestic dispute with my... with my butt.

# %% [markdown]
# Hasan Minhaj

# %%
hm_laugh_times = {
    'laugh_1': {'start': 10.0, 'end': 12.553}, 
    'laugh_2': {'start': 19.716, 'end': 25.960}, 
    'laugh_3': {'start': 35.217, 'end': 38.130}, 
    'laugh_5': {'start': 52.427, 'end': 54.516}, 
    'laugh_5': {'start': 59.617, 'end': 65.259},
    'laugh_6': {'start': 80.798, 'end': 90.037}
}

hm_laughter_map = create_laughter_map(hm_laugh_times, "/home/ada/humor/data/stand_up_dataset/hm/hm_output.json")

for laugh_num, info in hm_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

hm_sentences = make_sent_list(hm_laughter_map)
# Out:
# laugh 1
# Start Time: 10.0
# End Time: 12.553
# Funny Sentences: Are you fucking kidding? Thirteen episodes for this kid?
#
# laugh 2
# Start Time: 19.716
# End Time: 25.96
# Funny Sentences: Do you know when br0wn kids get slapped? Every br0wn birthday party.
#
# laugh 3
# Start Time: 35.217
# End Time: 38.13
# Funny Sentences: And that's what makes us tough and resilient. It's why we become cardiologists and win spelling bees.
#
# laugh 4
# Start Time: 59.617
# End Time: 65.259
# Funny Sentences: He's been slapped on camera.Of course he can spell "knaidel".Knaidel.Look at that face. Nothing.
#
# laugh 5
# Start Time: 80.798
# End Time: 90.037
# Funny Sentences: His brother is like, "I'm fucked. I'm fucked.

# %% [markdown]
# Hasan Minhaj 2

# %%
hm2_laugh_times = {
    'laugh_1': {'start': 21.149, 'end': 22.093}, 
    'laugh_2': {'start': 24.359, 'end': 26.564}, 
    'laugh_3': {'start': 43.435, 'end': 47.071}, 
    'laugh_4': {'start': 57.252, 'end': 58.076}
}

hm2_laughter_map = create_laughter_map(hm2_laugh_times, "/home/ada/humor/data/stand_up_dataset/hm2/hm2_output.json")

for laugh_num, info in hm2_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

hm2_sentences = make_sent_list(hm2_laughter_map)
# Out:
# laugh 1
# Start Time: 21.149
# End Time: 22.093
# Funny Sentences: One kid was like, "I know, getting into Stanford." He's like, "No, you have to live a life worth talking about, which is why I'm making it mandatory for everyone in this class to go to prom."
#
# laugh 2
# Start Time: 43.435
# End Time: 47.071
# Funny Sentences: Me, Jehovah's Witness girl, Korean exchange students, going to the prom? Thirty for 30?
#
# laugh 3
# Start Time: 57.252
# End Time: 58.076
# Funny Sentences: He walks over to the board, he pulls it down. It's a bracket with everybody's name on it leading up to the big dance.

# %% [markdown]
# Iliza Shlesinger

# %%
is_laugh_times = {
    'laugh_1': {'start': 18.016, 'end': 19.682}, 
    'laugh_2': {'start': 27.0834, 'end': 29.953}, 
    'laugh_3.': {'start': 43.7608, 'end': 45.129}, 
    'laugh_4': {'start': 61.0096, 'end': 65.1855}, 
    'laugh_5': {'start': 70.899, 'end': 72.245}, 
    'laugh_5': {'start': 79.163, 'end': 87.773}, 
    'laugh_6': {'start': 108.979, 'end': 109.358},
    'laugh_7': {'start': 112.762, 'end': 115.738}
}

is_laughter_map = create_laughter_map(is_laugh_times, "/home/ada/humor/data/stand_up_dataset/is/is_output.json")

for laugh_num, info in is_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

is_sentences = make_sent_list(is_laughter_map)
# Out:
# laugh 1
# Start Time: 18.016
# End Time: 19.682
# Funny Sentences: Now, I happen to think the very beginning of a new relationship is the most exciting part of the relationship. Granted, I'm not married yet, so, technically, I've only had beginnings of relationships.
#
# laugh 2
# Start Time: 27.0834
# End Time: 29.953
# Funny Sentences: I can't say empirically how fun being married is. I'll tell you on the next comedy special what that's all about.
#
# laugh 3
# Start Time: 43.7608
# End Time: 45.129
# Funny Sentences: You're both on your best behavior, it's still electric, you're not totally sure about the history of mental illness in each family. It's fun.
#
# laugh 4
# Start Time: 61.0096
# End Time: 65.1855
# Funny Sentences: I'd like to stay forever." Yes, come closer.
#
# laugh 5
# Start Time: 79.163
# End Time: 87.773
# Funny Sentences: In your 30s... In your 30s, homeboy knocks on the door, you open it, you're in combat boots, nothing else, and a garbage can on fire, you're, like, "Welcome to Fuckdome, Scott."
#
# laugh 6
# Start Time: 108.979
# End Time: 109.358
# Funny Sentences: Boy's coming over for the first time, you're trying to reconcile the beautiful home that your mother kept that you lived in growing up, with the beautiful home that, like, Pinterest says you're supposed to have. And the fact that you have no fucking money, so... Should I buy a rug or eat dinner?

# %% [markdown]
# Iliza Shlesinger 2

# %%
is2_laugh_times = {
    'laugh_1': {'start': 9.735, 'end': 15.507}, 
    'laugh_2': {'start': 33.498, 'end': 35.787}, 
    'laugh_3': {'start': 77.430, 'end': 78.8497}, 
    'laugh_4': {'start': 99.696, 'end': 101.115}, 
    'laugh_6': {'start': 109.649, 'end': 113.476}
}

is2_laughter_map = create_laughter_map(is2_laugh_times, "/home/ada/humor/data/stand_up_dataset/is2/is2_output.json")

for laugh_num, info in is2_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

is2_sentences = make_sent_list(is2_laughter_map)
# Out:
# laugh 1
# Start Time: 9.735
# End Time: 15.507
# Funny Sentences: You don't want to wear your daytime clothes, 'cause... 'cause it's nighttime. What if that was the end of my show?
#
# laugh 2
# Start Time: 33.498
# End Time: 35.787
# Funny Sentences: Just relax. You don't want to wear nipple tassels.
#
# laugh 3
# Start Time: 77.43
# End Time: 78.8497
# Funny Sentences: You show up in that, he'll be, like, "Oh, my god!" The blood's gonna go from here to his dick, he's gonna impale himself, he's gonna sue you, and you ain't got no money.
#
# laugh 4
# Start Time: 99.696
# End Time: 101.115
# Funny Sentences: I cried in front of everyone and... I ate that French fry from my car.
#
# laugh 5
# Start Time: 109.649
# End Time: 113.476
# Funny Sentences: He's, like, "Just kidding. Psych."

# %% [markdown]
# Jim Gaffigan

# %%
jg_laugh_times = {
    'laugh_1.wav': {'start': 17.846, 'end': 19.490}, 
    'laugh_2.wav': {'start': 28.813, 'end': 33.533}, 
    'laugh_3.wav': {'start': 36.351, 'end': 36.914}, 
    'laugh_4.wav': {'start': 53.493, 'end': 54.714}, 
    'laugh_5.wav': {'start': 68.968, 'end': 69.766}, 
    'laugh_6.wav': {'start': 73.665, 'end': 78.103}, 
    'laugh_7': {'start': 81.977, 'end': 84.889},
    'laugh_8': {'start': 87.472, 'end': 89.234}, 
    'laugh_9.wav': {'start': 91.676, 'end': 95.104}
}

jg_laughter_map = create_laughter_map(jg_laugh_times, "/home/ada/humor/data/stand_up_dataset/jg/jg_output.json")

for laugh_num, info in jg_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

jg_sentences = make_sent_list(jg_laughter_map)
# Out:
# laugh 1
# Start Time: 17.846
# End Time: 19.49
# Funny Sentences: That doesn't seem fair. I am now at the size, when I go in clothing stores sales people look at me like, "We got nothing for you.
#
# laugh 2
# Start Time: 28.813
# End Time: 33.533
# Funny Sentences: When I go out to eat, if I order a salad, the waiter's always like, "Aw. Look at you try."
#
# laugh 3
# Start Time: 36.351
# End Time: 36.914
# Funny Sentences: I'm always afraid he's gonna gather the whole staff, "The fat pig is trying, the fat pig is trying, I..." I've always talked about my weight in my stand up but in the past after shows if I ran into audience members they'd be like, "Jim, you're not that fat, you're not that fat."
#
# laugh 4
# Start Time: 53.493
# End Time: 54.714
# Funny Sentences: "You nailed it." I don't care.
#
# laugh 5
# Start Time: 68.968
# End Time: 69.766
# Funny Sentences: You know, when you like to eat, what's weird is people assume you enjoy cooking. (audience laughs) Well, you must know your way around the kitchen.
#
# laugh 6
# Start Time: 73.665
# End Time: 78.103
# Funny Sentences: I know where the food is.
#
# laugh 7
# Start Time: 81.977
# End Time: 84.889
# Funny Sentences: Look, I like to sleep. It doesn't mean I wanna build a bed.The truth is, I don't like to do anything.
#
# laugh 8
# Start Time: 87.472
# End Time: 89.234
# Funny Sentences: Like when I order delivery, I'm kind of annoyed they don't know what I want already.

# %% [markdown]
# Jim Gaffigan 2

# %%
jg2_laugh_times = {
    'laugh_1.wav': {'start':11.892, 'end': 13.087}, 
    'laugh_2': {'start': 17.552, 'end': 20.834}, 
    'laugh_3.wav': {'start': 23.450, 'end': 25.588}, 
    'laugh_4': {'start': 30.350, 'end': 33.624}, 
    'laugh_5.wav': {'start': 40.250, 'end': 43.140}, 
    'laugh_6.wav': {'start': 51.553, 'end': 53.033}, 
    'laugh_7.wav': {'start': 60.988, 'end': 62.526}, 
    'laugh_8.wav': {'start': 64.0300, 'end': 67.672}, 
    'laugh_9.wav': {'start': 78.363, 'end': 79.672},
    'laugh_9.wav': {'start': 86.610, 'end': 88.263}
}

jg2_laughter_map = create_laughter_map(jg2_laugh_times, "/home/ada/humor/data/stand_up_dataset/jg2/jg2_output.json")

for laugh_num, info in jg2_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

jg_sentences = make_sent_list(jg2_laughter_map)
# Out:
# laugh 1
# Start Time: 11.892
# End Time: 13.087
# Funny Sentences: It was a surprise birthday party for a dog. That's right, I have friends that are mentally ill.I went, I went.
#
# laugh 2
# Start Time: 17.552
# End Time: 20.834
# Funny Sentences: It was in my apartment building and I needed the material.And to be fair, the dog was surprised.
#
# laugh 3
# Start Time: 30.35
# End Time: 33.624
# Funny Sentences: Dog didn't know it was his birthday. The dog didn't know it had a birthday.
#
# laugh 4
# Start Time: 40.25
# End Time: 43.14
# Funny Sentences: The dog wasn't sure why people were in the apartment. It was the dog's third birthday, which in dog years doesn't matter.Someone made that up and we just went along with it.
#
# laugh 5
# Start Time: 51.553
# End Time: 53.033
# Funny Sentences: Okay. When I see a dog, I'll do math.
#
# laugh 6
# Start Time: 60.988
# End Time: 62.526
# Funny Sentences: There's not a dog sitting in a bar right now going, "I'm not three, I'm 21! I can legally drink!"
#
# laugh 7
# Start Time: 86.61
# End Time: 88.263
# Funny Sentences: It's a miracle! You're back after I don't know how long 'cause I'm a dog."

# %% [markdown]
# Joe List

# %%
jl_laugh_times = {
    'laugh_1.wav': {'start': 7.456820622986036, 'end': 12.396670247046186}, 
    'laugh_2.wav': {'start': 12.84360902255639, 'end': 17.148335123523093}, 
    'laugh_3.wav': {'start': 25.922448979591834, 'end': 27.145649838882917}, 
    'laugh_4.wav': {'start': 45.33114930182599, 'end': 53.75026852846401}, 
    'laugh_5.wav': {'start': 56.52599355531686, 'end': 62.00687432867883}, 
    'laugh_6.wav': {'start': 78.84940923737915, 'end': 87.57647690655209}
}

jl_laughter_map = create_laughter_map(jl_laugh_times, "/home/ada/humor/data/stand_up_dataset/ji/ji_output.json")

for laugh_num, info in jl_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

jl_sentences = make_sent_list(jl_laughter_map)
# Out:
# laugh 1
# Start Time: 7.456820622986036
# End Time: 12.396670247046186
# Funny Sentences: He knows all three body parts. I was hoping it was three doctors saving money, by sharing a small office.
#
# laugh 2
# Start Time: 12.84360902255639
# End Time: 17.148335123523093
# Funny Sentences: He's like, "I'm Bill, this is Susan, and Ted. "Ear, nose, throat.
#
# laugh 3
# Start Time: 25.922448979591834
# End Time: 27.145649838882917
# Funny Sentences: It's when you're ears ring, or buzz all the time. I don't know how you say it.
#
# laugh 4
# Start Time: 45.33114930182599
# End Time: 53.75026852846401
# Funny Sentences: All caps. And then I was like, "Shit, now I don't know how to say this word."
#
# laugh 5
# Start Time: 56.52599355531686
# End Time: 62.00687432867883
# Funny Sentences: This gentlemen is a doctor, he seems very smart. This fella seems, less smart, but, extremely adamant about the pronunciation of this word.
#
# laugh 6
# Start Time: 78.84940923737915
# End Time: 87.57647690655209
# Funny Sentences: "I hear everything, plus ringing, so. "I kind of have superpower hearing, if you think about it.

# %% [markdown]
# Joe List 2

# %%
jl2_laugh_times = {
    'laugh_1': {'start': 11.196, 'end': 19.140}, 
    'laugh_2': {'start': 28.809, 'end': 35.656}, 
    'laugh3': {'start': 36.453, 'end': 40.128}, 
    'laugh4': {'start': 46.263, 'end': 47.570}, 
    'laugh5': {'start': 50.612, 'end': 53.391}, 
    'laugh6': {'start': 54.398, 'end': 59.154}, 
    'laugh7': {'start': 69.954, 'end': 72.391}, 
    'laugh8': {'start': 75.288, 'end': 77.264}, 
    'laugh9': {'start': 80.169, 'end': 85.352}, 
    'laugh10': {'start': 100.918, 'end': 105.650}, 
    'laugh11':{'start': 111.023, 'end': 114.877}, 
    'laugh12': {'start': 124.376, 'end': 128.828}, 
}

jl2_laughter_map = create_laughter_map(jl2_laugh_times, "/home/ada/humor/data/stand_up_dataset/ji2/ji2_output.json")

for laugh_num, info in jl2_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

jl2_sentences = make_sent_list(jl2_laughter_map)
# Out:
# laugh 1
# Start Time: 11.196
# End Time: 19.14
# Funny Sentences: You can be in the second to last row. This one guy behind, you're like what a fucking idiot back there.
#
# laugh 2
# Start Time: 28.809
# End Time: 35.656
# Funny Sentences: The whole flight he's like. [yawns] For like five hours.
#
# laugh 3
# Start Time: 36.453
# End Time: 40.128
# Funny Sentences: [yawns] I wanted him to die, I swear to God.
#
# laugh 4
# Start Time: 46.263
# End Time: 47.57
# Funny Sentences: First of all, you don't need to make a noise when you yawn. That's a decision, he's deciding to do that.
#
# laugh 5
# Start Time: 50.612
# End Time: 53.391
# Funny Sentences: It's like, if you were hungry on a plane, you were like, I'm hungry.
#
# laugh 6
# Start Time: 54.398
# End Time: 59.154
# Funny Sentences: Well you're all right? Yeah, yeah I'm hungry.
#
# laugh 7
# Start Time: 69.954
# End Time: 72.391
# Funny Sentences: of how I came to be tired. Don't fall for it, it's a trap.
#
# laugh 8
# Start Time: 75.288
# End Time: 77.264
# Funny Sentences: Plus isn't it fun to not ask somebody a question when they really want you to ask them a question? You ever do that when someone was like, "I had a wild night last night."
#
# laugh 9
# Start Time: 80.169
# End Time: 85.352
# Funny Sentences: and then you're like, "Neat." And then you just walked away.
#
# laugh 10
# Start Time: 101.23718148725948
# End Time: 101.89289304905529
# Funny Sentences: Two years in a row, he wore a cowboy hat. He also had a huge handlebar mustache.
#
# laugh 11
# Start Time: 107.60695094470445
# End Time: 112.12667706708267
# Funny Sentences: None of that matters, but it's important to me that you know that.
#
# laugh 12
# Start Time: 115.59258103657479
# End Time: 118.70721095510486
# Funny Sentences: He did not look like his job description. He looked like he should be the conductor on a locomotive powered by confetti.
#
# laugh 13
# Start Time: 120.72118218062054
# End Time: 123.53137458831685
# Funny Sentences: But, instead, he made his living in murder. He was the weirdest goddamn person I ever saw in my entire life.

# %% [markdown]
# Jimmy Yang

# %%
jy_laugh_times = {
    'laugh1': {'start': 4.723, 'end': 6.042}, 
    'laugh2': {'start': 15.145, 'end': 17.092}, 
    'laugh3': {'start': 25.1675, 'end': 27.876}, 
    'laugh4': {'start': 35.655, 'end': 36.360}, 
    'laugh5': {'start': 40.282, 'end': 41.856}, 
    'laugh6': {'start': 53.297, 'end': 57.367}, 
    'laugh7': {'start': 60.736, 'end': 62.175}, 
    'laugh7': {'start': 72.351, 'end': 76.204},
    'laugh6': {'start': 81.672, 'end': 83.525}, 
    'laugh8': {'start': 88.152, 'end': 89.044}
}

jy_laughter_map = create_laughter_map(jy_laugh_times, "/home/ada/humor/data/stand_up_dataset/jy/jy_output.json")

for laugh_num, info in jy_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

jy_sentences = make_sent_list(jy_laughter_map)
# Out:
# laugh 1
# Start Time: 4.723
# End Time: 6.042
# Funny Sentences: We just go to BTS concerts. That's how we do that parking lot pimping.I've been dating a lot of tall girls lately, because it makes me look successful.
#
# laugh 2
# Start Time: 25.1675
# End Time: 27.876
# Funny Sentences: But some of them like to wear heels. That's just disrespect.
#
# laugh 3
# Start Time: 35.655
# End Time: 36.36
# Funny Sentences: I'm like, your ass is at my eye level right now. Neither of us look good, OK?
#
# laugh 4
# Start Time: 40.282
# End Time: 41.856
# Funny Sentences: I look like a child, and you look like a child molester.Last time- the last time I took a tall girl to this concert- I don't know if you guys know this, but apparently, tall people have fun at concerts.
#
# laugh 5
# Start Time: 81.672
# End Time: 83.525
# Funny Sentences: I had enough. So I just looked up at her, I was like, hey!
#
# laugh 6
# Start Time: 88.152
# End Time: 89.044
# Funny Sentences: Pick me up.

# %% [markdown]
# Jimmy Yang

# %%
jy2_laugh_times = {
    'laugh1': {'start': 28.42559627690518, 'end': 29.97865037812682}, 
    'laugh2': {'start': 38.37926119837115, 'end': 41.508900523560214}, 
    'laugh3': {'start': 53.25093077370565, 'end': 56.28644560791158}, 
    'laugh4': {'start': 66.42835951134381, 'end': 69.39328097731239}
}

jy2_laughter_map = create_laughter_map(jy2_laugh_times, "/home/ada/humor/data/stand_up_dataset/jy2/jy2_output.json")

for laugh_num, info in jy2_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

jy2_sentences = make_sent_list(jy2_laughter_map)
# Out:
# laugh 1
# Start Time: 28.42559627690518
# End Time: 29.97865037812682
# Funny Sentences: They judge the TV. This is like, I'm just sitting next to my dad on the couch, and he's wearing his, like, old Asian man costume, which is just a wife beater and tighty-whiteys.
#
# laugh 2
# Start Time: 38.37926119837115
# End Time: 41.508900523560214
# Funny Sentences: He's just sitting there, arms folded, judging the TV like-He's made some random noises around the house.
#
# laugh 3
# Start Time: 53.25093077370565
# End Time: 56.28644560791158
# Funny Sentences: Now whenever he sneezes, it's never just a sneeze. It's like a whole tsunami of sound waves that comes after.
#
# laugh 4
# Start Time: 66.42835951134381
# End Time: 69.39328097731239
# Funny Sentences: Ay, shit.Oh! I'm like, what the fuck, Dad, just have an orgasm?

# %% [markdown]
# Louis_CK_2

# %%
lck2_laugh_times = {
    'laugh1' :{'start': 19.604329896907217, 'end': 31.159823269513993}, 
    'laugh2': {'start': 56.859617083946986, 'end': 57.33030927835052}, 
    'laugh3': {'start': 64.0376730486009, 'end': 65.28500736377026}, 
}

lck2_laughter_map = create_laughter_map(lck2_laugh_times, "/home/ada/humor/data/stand_up_dataset/lck2/lck2_output.json")

for laugh_num, info in lck2_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

lck2_sentences = make_sent_list(lck2_laughter_map)
# Out:
# laugh 1
# Start Time: 19.604329896907217
# End Time: 31.159823269513993
# Funny Sentences: They're in our lives and they know nothing about what's happening. You ever been having, like, a dramatic moment in your family, like, you're in the living room telling the kids that grandma died, and everybody's crying, and the dog's sitting there like..."I know you!
#
# laugh 2
# Start Time: 56.859617083946986
# End Time: 57.33030927835052
# Funny Sentences: I'm sorry, I... I don't know anything now.
#
# laugh 3
# Start Time: 64.0376730486009
# End Time: 65.28500736377026
# Funny Sentences: It's right there." And the dog just looks at your finger 'cause there's just no way he's gonna get this concept that there's an invisible line... ...that he can follow with his imagination.

# %% [markdown]
# Nate_Bargatze

# %%
nb_laugh_times = {
    'laugh1': {'start': 12.98894533139816, 'end': 16.958442186744072}, 
    'laugh2': {'start': 20.787010159651665, 'end': 23.300241896468307}, 
    'laugh3': {'start': 39.95333817126269, 'end': 41.33913884857281}, 
    'laugh4': {'start': 52.28461538461538, 'end': 55.0562167392356}, 
    'laugh5': {'start': 66.98819545234639, 'end': 74.99765360425737}, 
    'laugh6': {'start': 85.68476052249636, 'end': 90.49983067247217}, 
    'laugh7' :{'start': 95.1035074987905, 'end': 97.07651185292694}
}

nb_laughter_map = create_laughter_map(nb_laugh_times, "/home/ada/humor/data/stand_up_dataset/nb/nb_output.json")

for laugh_num, info in nb_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

nb_sentences = make_sent_list(nb_laughter_map)
# Out:
# laugh 1
# Start Time: 12.98894533139816
# End Time: 16.958442186744072
# Funny Sentences: So a lot of people ask, "Did you name her after Harper Lee, the author of To Kill a Mockingbird?" And, you know, I've never thought about an author a day in my life, so... That never occurred to me.
#
# laugh 2
# Start Time: 20.787010159651665
# End Time: 23.300241896468307
# Funny Sentences: I mean, my middle name is Lee, and it just never crossed my mind.
#
# laugh 3
# Start Time: 39.95333817126269
# End Time: 41.33913884857281
# Funny Sentences: I've never seen someone cry this much. It's over nothing.
#
# laugh 4
# Start Time: 52.28461538461538
# End Time: 55.0562167392356
# Funny Sentences: She just sits there on her iPad. She wants to be a YouTuber, which, as a comedian, makes me furious.
#
# laugh 5
# Start Time: 66.98819545234639
# End Time: 74.99765360425737
# Funny Sentences: None of this is anywhere but my phone. I got 90 hours of this.
#
# laugh 6
# Start Time: 85.68476052249636
# End Time: 90.49983067247217
# Funny Sentences: "You want to see me open it?" It's got five billion views.
#
# laugh 7
# Start Time: 95.1035074987905
# End Time: 97.07651185292694
# Funny Sentences: It looks like we buy her nothing, like, we just show her. "If you wanna watch a kid have fun, but you'll never have fun in this house!"

# %% [markdown]
# Nate_Bargatze 2

# %%
nb2_laugh_times = {
    'laugh1': {'start': 10.171, 'end': 12.779}, 
    'laugh2': {'start': 15.292, 'end': 19.380},
    'laugh3': {'start': 25.393, 'end': 27.907}, 
    'laugh_4': {'start': 43.575, 'end': 46.371}, 
    'laugh5': {'start': 49.8712, 'end': 51.703}, 
    'laugh6': {'start': 58.881, 'end': 62.509}, 
    'laugh7': {'start': 67.865, 'end': 70.543}, 
    'laugh8': {'start': 90.537, 'end': 93.376}
}

nb2_laughter_map = create_laughter_map(nb2_laugh_times, "/home/ada/humor/data/stand_up_dataset/nb2/nb2_output.json")

for laugh_num, info in nb2_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

nb_sentences = make_sent_list(nb2_laughter_map)
# Out:
# laugh 1
# Start Time: 10.171
# End Time: 12.779
# Funny Sentences: Third grade, you're like, "Okay." They throw some stuff in, you're like, "Oh, all right.
#
# laugh 2
# Start Time: 15.292
# End Time: 19.38
# Funny Sentences: All right." It's, uh... "Okay, learning it earlier than we used to, huh?"
#
# laugh 3
# Start Time: 25.393
# End Time: 27.907
# Funny Sentences: Just give it to parents that never learned it. Uh...
#
# laugh 4
# Start Time: 43.575
# End Time: 46.371
# Funny Sentences: If you don't know Common Core, it's just a new math. And the goal of Common Core is to use one sheet of paper for every problem.
#
# laugh 5
# Start Time: 49.8712
# End Time: 51.703
# Funny Sentences: You... You just want to keep breaking the problem down. You put the problem at the top, and it just keeps going.
#
# laugh 6
# Start Time: 58.881
# End Time: 62.509
# Funny Sentences: Just do that at the top. I don't even know what we're doing."
#
# laugh 7
# Start Time: 67.865
# End Time: 70.543
# Funny Sentences: Old math still... I don't get incorrect change everywhere, just going, "This stupid old math!"
#
# laugh 8
# Start Time: 90.537
# End Time: 93.376
# Funny Sentences: "No, it works. I use it, a lot of people still use it, but the new way is to go jump the fence and come in the back and meet me at this same spot."

# %% [markdown]
# Nate_Bargatze_TK

# %%
nb_tk_laugh_times = {
    'laugh1': {'start': 9.292, 'end': 11.846}, 
    'laugh2': {'start': 16.367, 'end': 22.782},
    'laugh3': {'start': 26.020, 'end': 27.421}, 
    'laugh4': {'start': 48.091, 'end': 50.253},
    'laugh6': {'start': 55.689, 'end': 59.162},
    'laugh7': {'start': 72.160, 'end': 74.112},
    'laugh8': {'start': 80.708, 'end': 83.245}
}

nb_tk_laughter_map = create_laughter_map(nb_tk_laugh_times, "/home/ada/humor/data/stand_up_dataset/nb_tk/nbtk_output.json")

for laugh_num, info in nb_tk_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

nb_tk2_sentences = make_sent_list(nb_tk_laughter_map)
# Out:
# laugh 1
# Start Time: 9.292
# End Time: 11.846
# Funny Sentences: He's done that my entire life. He was a clown at the very beginning, just in case you're like, "How do you get into something like that?"
#
# laugh 2
# Start Time: 16.367
# End Time: 22.782
# Funny Sentences: There's two steps. You can take them in either order.
#
# laugh 3
# Start Time: 26.02
# End Time: 27.421
# Funny Sentences: It was never weird to me. I thought everybody's dad was a clown.
#
# laugh 4
# Start Time: 48.091
# End Time: 50.253
# Funny Sentences: And... The Easter Bunny was in the passenger seat.
#
# laugh 5
# Start Time: 55.689
# End Time: 59.162
# Funny Sentences: That's the first thing that I remember, to my life. If you want to know how you get into comedy, that's a pretty good nudge.
#
# laugh 6
# Start Time: 72.16
# End Time: 74.112
# Funny Sentences: Like, he couldn't sit normal, so his head was bent to the side. And I remember he had his seat belt on, and he's just like... and I was like...
#
# laugh 7
# Start Time: 80.708
# End Time: 83.245
# Funny Sentences: I like to think about all the other people that saw that. Just in the car next to them, just at a red light, you're like, "I didn't even know they hung out like that."

# %% [markdown]
# Nate_Bargatze_TK_2

# %%
nb_tk2_laugh_times = {
    'laugh1': {'start': 13.984, 'end': 15.303},
    'laugh2': {'start': 24.249, 'end': 28.361},  
    'laugh3': {'start': 37.646, 'end': 39.765}, 
    'laugh4': {'start': 50.124, 'end': 51.042}, 
    'laugh5': {'start': 55.3513, 'end': 56.410}, 
    'laugh6': {'start': 64.180, 'end': 65.875},
    'laugh7': {'start': 70.216, 'end': 76.073},
}

nb_tk2_laughter_map = create_laughter_map(nb_tk2_laugh_times, "/home/ada/humor/data/stand_up_dataset/nb_tk2/nbtk2_output.json")

for laugh_num, info in nb_tk2_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

nb_tk2_sentences = make_sent_list(nb_tk2_laughter_map)
# Out:
# laugh 1
# Start Time: 13.984
# End Time: 15.303
# Funny Sentences: It was right outside Louisville, Kentucky, where my parents are from. And my cousin's name is Tuesday, which is a good start.
#
# laugh 2
# Start Time: 24.249
# End Time: 28.361
# Funny Sentences: The invitation said, "Tuesday's getting married, rehearsal's Friday, wedding's Saturday." People were like, "We gotta be there Monday for this wedding?
#
# laugh 3
# Start Time: 37.646
# End Time: 39.765
# Funny Sentences: I look like I work there. -Uh... Everybody else just has a football or basketball jersey on.
#
# laugh 4
# Start Time: 50.124
# End Time: 51.042
# Funny Sentences: No shirt. They forgot his shirt, and instead of waiting to go get it, he was like, "Let's do it without it."
#
# laugh 5
# Start Time: 64.18
# End Time: 65.875
# Funny Sentences: He has a body that you're like, "Put your jacket on backwards. Flip it around."
#
# laugh 6
# Start Time: 70.216
# End Time: 76.073
# Funny Sentences: Then you see his back, and you're like, "Oof. All right, go back to regular way.

# %% [markdown]
# Russell_Peters

# %%
rp_laugh_times = {
    'laugh1': {'start': 10.549, 'end': 11.106}, 
    'laugh2': {'start': 17.367, 'end': 18.713}, 
    'laugh3': {'start': 23.074, 'end': 23.734}, 
    'laugh4': {'start': 38.771, 'end': 41.336}, 
    'laugh5': {'start': 51.251, 'end': 54.234},
    'laugh7': {'start': 70.283, 'end': 71.202}
}

rp_laughter_map = create_laughter_map(rp_laugh_times, "/home/ada/humor/data/stand_up_dataset/rp/rp_output.json")

for laugh_num, info in rp_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

rp_sentences = make_sent_list(rp_laughter_map)
# Out:
# laugh 1
# Start Time: 10.549
# End Time: 11.106
# Funny Sentences: He goes, look, you're a 48-year-old Indian man. I'm like, that's really fucking racist, but since you asked, I have acid reflux.
#
# laugh 2
# Start Time: 17.367
# End Time: 18.713
# Funny Sentences: I don't know.
#
# laugh 3
# Start Time: 23.074
# End Time: 23.734
# Funny Sentences: Does anybody else- who else has acid reflux in here? First of all, you're lying to me right now.
#
# laugh 4
# Start Time: 38.771
# End Time: 41.336
# Funny Sentences: It's inevitable. There's no way you can consume the food that we eat with that much spice, and that much oil, and that much butter, and not just have it burn a hole in your- as my dad would say- your esophagus.
#
# laugh 5
# Start Time: 51.251
# End Time: 54.234
# Funny Sentences: No, no, son, esophagus. I don't care whose phagus you think this is.
#
# laugh 6
# Start Time: 70.283
# End Time: 71.202
# Funny Sentences: You do, do you. He's like, I know, I have it, but I don't want to say because my shirt looks like turmeric,

# %% [markdown]
# Russell_Peters 2

# %%
rp2_laugh_times = {
    'laugh1': {'start': 17.69572953736655, 'end': 19.65405693950178}, 
    'laugh2': {'start': 21.423629893238434, 'end': 23.42914590747331}, 
    'laugh3': {'start': 25.576227758007118, 'end': 27.227829181494663}, 
    'laugh4': {'start': 32.30060498220641, 'end': 38.151992882562276}, 
    'laugh5': {'start': 50.0435231316726, 'end': 51.12886120996441}, 
    'laugh6': {'start': 55.51740213523132, 'end': 57.66448398576512}, 
    'laugh7': {'start': 61.36879003558719, 'end': 64.76637010676157}
}

rp2_laughter_map = create_laughter_map(rp2_laugh_times, "/home/ada/humor/data/stand_up_dataset/rp2/rp2_output.json")

for laugh_num, info in rp2_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

rp2_sentences = make_sent_list(rp2_laughter_map)
# Out:
# laugh 1
# Start Time: 17.69572953736655
# End Time: 19.65405693950178
# Funny Sentences: I was like, if I have twin girls- because you've got to have fun with the names. If I have twin girls, these are going to be my daughters, it's going to be Kate and Duplicate.
#
# laugh 2
# Start Time: 21.423629893238434
# End Time: 23.42914590747331
# Funny Sentences: These are my boys, it's Pete and Repeat.
#
# laugh 3
# Start Time: 25.576227758007118
# End Time: 27.227829181494663
# Funny Sentences: If I had twins with a black girl, this is Tyrone and Tyclone.
#
# laugh 4
# Start Time: 32.30060498220641
# End Time: 38.151992882562276
# Funny Sentences: That's your way of going, look. Look at how good my balls are.
#
# laugh 5
# Start Time: 50.0435231316726
# End Time: 51.12886120996441
# Funny Sentences: Or because you're Punjabi, look at how good my junk they are. Looks at this.Look at how good my balls are.
#
# laugh 6
# Start Time: 55.51740213523132
# End Time: 57.66448398576512
# Funny Sentences: My balls are so strong, they made one kid and then it made the exact same kid right away.
#
# laugh 7
# Start Time: 61.36879003558719
# End Time: 64.76637010676157
# Funny Sentences: You lift up your balls, sponsored by Xerox. Sponsored by Xerox.

# %% [markdown]
# Sam Morill

# %%
sm_laugh_times = {
    'l1': {'start': 9.583, 'end': 15.102}, 
    'l2': {'start': 21.481, 'end': 25.540}, 
    'l3': {'start': 28.657, 'end': 30.060}, 
    'l4': {'start': 43.711, 'end': 47.941}, 
    'l5': {'start': 51.8923, 'end': 53.855}, 
    'l6': {'start': 56.099, 'end': 57.642}, 
    'l7': {'start': 59.629, 'end': 64.210}, 
    'l8': {'start': 67.623, 'end': 68.021}, 
    'l9': {'start': 78.300, 'end': 80.526}, 
    'l10': {'start': 83.8923, 'end': 87.175}, 
    'l11': {'start': 107.6833, 'end': 109.114},
    'l12': {'start': 114.186, 'end': 115.612}, 
    'l13': {'start': 123.0456, 'end': 124.653}, 
    'l14': {'start': 128.258, 'end': 129.497}, 
    'l15': {'start': 130.736, 'end': 133.587}, 
    'l16': {'start': 135.364, 'end': 136.509}, 
    'l17': {'start': 140.389, 'end': 143.171}, 
    'l18': {'start': 160.609, 'end': 162.035}, 
    'l19': {'start': 166.172, 'end': 172.366}, 
    'l20': {'start': 178.233, 'end': 179.776}
}

sm_laughter_map = create_laughter_map(sm_laugh_times, "/home/ada/humor/data/stand_up_dataset/sm/sm_output.json")

for laugh_num, info in sm_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

sm_sentences = make_sent_list(sm_laughter_map)
# Out:
# laugh 1
# Start Time: 9.583
# End Time: 15.102
# Funny Sentences: Obviously, it was an accident. No one at the party was like I'm gonna roofie that hairy boy over there.
#
# laugh 2
# Start Time: 21.481
# End Time: 25.54
# Funny Sentences: I just told a room full of people I got roofied. I did not see one concerned face in here.
#
# laugh 3
# Start Time: 28.657
# End Time: 30.06
# Funny Sentences: Everyone in here is like I assume things worked out for you, and they did. Still weird, though.
#
# laugh 4
# Start Time: 43.711
# End Time: 47.941
# Funny Sentences: And then I chugged it, and I woke up the next morning, and I was like oh. That guy's a sexual predator.
#
# laugh 5
# Start Time: 51.8923
# End Time: 53.855
# Funny Sentences: And my friend said you ruined his night. And I was like, that's not how I want to think about it, you know?
#
# laugh 6
# Start Time: 56.099
# End Time: 57.642
# Funny Sentences: You don't want to think of yourself as a -block to some monster.
#
# laugh 7
# Start Time: 59.629
# End Time: 64.21
# Funny Sentences: I prefer to think of myself as an accidental hero.
#
# laugh 8
# Start Time: 67.623
# End Time: 68.021
# Funny Sentences: Statistically, you know... I can't, you guys.
#
# laugh 9
# Start Time: 78.3
# End Time: 80.526
# Funny Sentences: It's kind of like if I was driving drunk and I just swerved and accidentally hit a mugger. And some woman is like, "My hero," and I'm like if you say so, but I might have a substance abuse problem, so...
#
# laugh 10
# Start Time: 107.6833
# End Time: 109.114
# Funny Sentences: I was like, yeah, that's a very helpful example. That's always the crossroads I find myself at at 4:57 a.m.
#
# laugh 11
# Start Time: 114.186
# End Time: 115.612
# Funny Sentences: I can't tell you how often I'm coming out of a blackout like I should have done doubles instead. That's...
#
# laugh 12
# Start Time: 123.0456
# End Time: 124.653
# Funny Sentences: You tell me to replace an addiction with cardio, that's very helpful. I'm gonna start walking into halfway houses full of crack heads like have you guys done Zumba?
#
# laugh 13
# Start Time: 128.258
# End Time: 129.497
# Funny Sentences: It's so much better than crack.
# End Time: 82.391
# Funny Sentences: But what I started doing now is I leave the lights off. And when I go the bathroom, I just speak to myself in a Russian accent.
#
# laugh 5
# Start Time: 84.612
# End Time: 86.553
# Funny Sentences: I feel like I'm the most dangerous thing in the night. You'll find me at three a.m., barefoot, walking to the toilet, like, "Yes.
#
# laugh 6
# Start Time: 90.69
# End Time: 95.057
# Funny Sentences: Big boy got to make a pee-pee. No trouble over here.
#
# laugh 7
# Start Time: 101.726
# End Time: 105.023
# Funny Sentences: I feel safe, like even if there's a monster under the bed, he'd be like, "Is that a Russian?" There's just something about that Russian accent.
#
# laugh 8
# Start Time: 174.178
# End Time: 175.568
# Funny Sentences: As soon as he says, "Don't be such a bitch!" Just be like... [Russian accent] "You want to see bitch?"

# %% [markdown]
# Trevor Noah 2

# %%
tn2_laugh_times = {
    'l1': {'start': 13.273, 'end': 17.662}, 
    'l2': {'start': 26.474, 'end': 27.698}, 
    'l3': {'start': 38.852, 'end': 40.535}, 
    'l4': {'start': 49.724, 'end': 51.042}, 
    'l5': {'start': 60.423, 'end': 62.326}, 
    'l6': {'start': 74.216, 'end': 78.397}, 
}

tn2_laughter_map = create_laughter_map(tn2_laugh_times, "/home/ada/humor/data/stand_up_dataset/tn2/tn2_output.json")

for laugh_num, info in tn2_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

tn2_sentences = make_sent_list(tn2_laughter_map)
# Out:
# laugh 1
# Start Time: 13.273
# End Time: 17.662
# Funny Sentences: You are destined for greatness. You can't be running in the streets: "And a Kit Kat, please."
#
# laugh 2
# Start Time: 26.474
# End Time: 27.698
# Funny Sentences: "I'm not telling you." [laughs] It just doesn't work.
#
# laugh 3
# Start Time: 38.852
# End Time: 40.535
# Funny Sentences: I remember when Nelson Mandela was still alive, and he would tell jokes at press conferences and events, and no one would laugh. Because everyone thought a man who had been in jail for 27 years couldn't make a joke.
#
# laugh 4
# Start Time: 49.724
# End Time: 51.042
# Funny Sentences: It was partly because of that voice. He would tell the joke, and it would just sound too epic for people to laugh.
#
# laugh 5
# Start Time: 60.423
# End Time: 62.326
# Funny Sentences: Let him in!" "No.
#
# laugh 6
# Start Time: 74.216
# End Time: 78.397
# Funny Sentences: Who are we?' Oh, my God!"

# %% [markdown]
# Tom Segura

# %%
ts_laugh_times = {
    'l1':{'start': 11.892, 'end': 12.529}, 
    'l1':{'start': 15.496, 'end': 18.245}, 
    'l1':{'start': 22.420, 'end': 25.351}, 
    'l2':{'start': 31.113, 'end': 32.456}, 
    'l3': {'start': 43.950, 'end': 46.023}, 
    'l4': {'start': 56.503, 'end': 58.176},
    'l5': {'start': 61.4021, 'end': 63.451}
}

ts_laughter_map = create_laughter_map(ts_laugh_times, "/home/ada/humor/data/stand_up_dataset/ts/ts_output.json")

for laugh_num, info in ts_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

ts_sentences = make_sent_list(ts_laughter_map)
# Out:
# laugh 1
# Start Time: 22.42
# End Time: 25.351
# Funny Sentences: This dude's like, "You trying to get a sack?" -I was like, "Oh, shit.
#
# laugh 2
# Start Time: 31.113
# End Time: 32.456
# Funny Sentences: And he goes, "We just need to go get it." I was like, "You don't fuckin' have it?
#
# laugh 3
# Start Time: 43.95
# End Time: 46.023
# Funny Sentences: You stay here and watch my place." And I was like...
#
# laugh 4
# Start Time: 56.503
# End Time: 58.176
# Funny Sentences: Inside? Paralysis.
#
# laugh 5
# Start Time: 61.4021
# End Time: 63.451
# Funny Sentences: But what I said was, "That's what's up." -Like, yeah, man.

# %% [markdown]
# Tom Segura 2

# %%
ts2_laugh_times = {
    'l1': {'start': 7.912, 'end': 9.966}, 
    'l2': {'start': 17.212, 'end': 19.496}, 
    'l1': {'start': 44.776, 'end': 47.440}, 
    'l2': {'start': 50.788, 'end': 53.995}, 
    'l3': {'start': 58.970, 'end': 60.597}
}

ts2_laughter_map = create_laughter_map(ts2_laugh_times, "/home/ada/humor/data/stand_up_dataset/ts2/ts2_output.json")

for laugh_num, info in ts2_laughter_map.items():
    print(laugh_num)
    print("Start Time:", info[0])
    print("End Time:", info[1])
    print("Funny Sentences:", info[2])
    print()

ts2_sentences = make_sent_list(ts2_laughter_map)
# Out:
# laugh 1
# Start Time: 44.776
# End Time: 47.44
# Funny Sentences: -And you hit that. And then you see it close, and you're like...
#
# laugh 2
# Start Time: 50.788
# End Time: 53.995
# Funny Sentences: Sometimes, a second later it opens, and you're like, "Fuck!"
#
# laugh 3
# Start Time: 58.97
# End Time: 60.597
# Funny Sentences: You get nervous energy, like you're a kid. You're like, "I'm in trouble."

# %% [markdown]
# ## Create Pandas Data

# %%
import pandas as pd

# %%
combined_data = {}
i = 1
for comedian, info in [("Donald_Glover", dg_laughter_map), ("Donald_Glover_2", dg2_laughter_map), 
                       ("Anthony_Jeselnik", aj_laughter_map), ("Anthony_Jeselnik_2", aj2_laughter_map),
                       ("Chelsea_Peretti", cp_laughter_map), ("Chelsea_Peretti_2", cp2_laughter_map),
                       ("Louis_CK", lck_laughter_map), ("Louis_CK_2", lck2_laughter_map), 
                       ("John_Mulaney", jm_laughter_map), ("John_Mulaney_2", jm2_laughter_map),
                       ("Ali_Wong", aw_laughter_map), ("Ali_Wong_2", aw2_laughter_map),
                       ("Hasan_Minhaj", hm_laughter_map), ("Hasan_Minhaj_2", hm2_laughter_map),
                       ("Iliza_Shlesinger", is_laughter_map), ("Iliza_Shlesinger_2", is2_laughter_map),
                       ("Jim_Gaffigan", jg_laughter_map), ("Jim_Gaffigan_2", jg2_laughter_map),
                       ("Joe_List", jl_laughter_map), ("Joe_List_2", jl2_laughter_map),
                       ("Jimmy_Yang", jy_laughter_map), ("Jimmy_Yang_2", jy2_laughter_map),
                       ("Nate_Bargatze", nb_laughter_map), ("Nate_Bargatze_2", nb2_laughter_map),
                       ("Nate_Bargatze_TK", nb_tk_laughter_map), ("Nate_Bargatze_TK_2", nb_tk2_laughter_map),
                       ("Russell_Peters", rp_laughter_map), ("Russell_Peters_2", rp2_laughter_map),
                       ("Sam_Morril", sm_laughter_map), ("Sam_Morril_2", sm2_laughter_map),
                       ("Trevor_Noah", tn_laughter_map), ("Trevor_Noah_2", tn2_laughter_map),
                       ("Tom_Segura", ts_laughter_map), ("Tom_Segura_2", ts2_laughter_map)]:
  for key, value in info.items():
    combined_data[i] = [comedian, value[0], value[1], value[2]]
    i+=1

# %%
for key, value in combined_data.items():
  print(key, value)
# Out:
# 1 ['Donald_Glover', 17.268, 19.352, 'Just tears, he was giving me this mean mug, he was like... I was like, what the fuck is wrong with this kid?']
# 2 ['Donald_Glover', 32.292, 34.182, 'The sweetest thing he was allowed was mints. He was just allowed to have mints.']
# 3 ['Donald_Glover', 38.79, 41.441, 'So he would steal mints by the handful. So his breath was so fresh... the vapors from his own mouth made his eyes water.']
# 4 ['Donald_Glover', 44.903, 53.441, 'Like, he\'d be like, "Hello!"']
# 5 ['Donald_Glover', 68.88, 73.824, "You know, they were cool. You know, we'd trade jerk- chicken recipes and stuff."]
# 6 ['Donald_Glover', 90.491, 94.607, 'And he... he was just a mean-spirited kid, like, he kind Of... Like, he watched HBO just a little too early and was just kind of a mean kid in general, so he would just come through and just...He wanted to get to his slide, so he just pushed over this little girl, she fell over, and her Trinidadian babysitter comes over and goes, "Hey!']
# 7 ['Donald_Glover', 107.842, 110.958, 'And she goes, "Don\'t you talk to me like that, I am a grown-up, you will respect me." And he goes, "Suck my d!ck!"']
# 8 ['Donald_Glover', 125.042, 128.508, 'I shit you not... The lady goes, "Someone betta get this little niglet away from me."']
# 9 ['Donald_Glover_2', 20.288, 26.293, 'I can\'t believe this happened so close to us." And she goes, "Yeah, well, "if anybody ever tries to rape me, I\'m just gonna shit on \'em."']
# 10 ['Donald_Glover_2', 40.953, 43.275, 'I have no problem." Uh... Two things, lady.']
# 11 ['Donald_Glover_2', 45.151, 46.488, "Number one, he's a rapist."]
# 12 ['Donald_Glover_2', 49.068, 51.297, 'So his tolerance for gross stuff is probably pretty high.']
# 13 ['Donald_Glover_2', 56.246, 71.937, 'Number two... you can shit on command? Like, you can just... You can just poop whenever you want to?']
# 14 ['Donald_Glover_2', 77.121, 84.51, 'No, I can\'t poop whenever I want. Somebody can run down... down the stage right now and pull out a gun and be like, "Shit yourself!']
# 15 ['Donald_Glover_2', 92.086, 93.329, 'I\'d be like, "Blow my head off." I can\'t do it, I can\'t do it, I\'m not... Me and my butt are, like, always on the third date, I feel like.']
# 16 ['Donald_Glover_2', 96.542, 97.152, "I feel like, me, I'm always like, come on, let's... hurry up, let's do this. And my butt's always like, stop rushing me, when the time is right."]
# 17 ['Donald_Glover_2', 108.207, 110.076, "I'm not in love yet. That was me in a domestic dispute with my... with my butt."]
# 18 ['Anthony_Jeselnik', 16.898, 19.405, 'When I was a kid, we were poor. So poor I remember, just so I could go to my senior prom, just so I could go to my senior prom, I had to sell my U.S. passport on the street.']
# 19 ['Anthony_Jeselnik', 29.085, 31.1, 'Of course this was before 9/11 so... my bad, everybody. Weird joke to clap for, but sure.']
# 20 ['Anthony_Jeselnik', 34.874, 36.233, "My mom actually should've been on one of the planes that crashed on 9/11."]
# 21 ['Anthony_Jeselnik', 43.756, 48.912, "I think.I mean, don't get me wrong, I loved my mother."]
# 109 ['Jim_Gaffigan', 53.493, 54.714, '"You nailed it." I don\'t care.']
# 110 ['Jim_Gaffigan', 68.968, 69.766, "You know, when you like to eat, what's weird is people assume you enjoy cooking. (audience laughs) Well, you must know your way around the kitchen."]
# 111 ['Jim_Gaffigan', 73.665, 78.103, 'I know where the food is.']
# 112 ['Jim_Gaffigan', 81.977, 84.889, "Look, I like to sleep. It doesn't mean I wanna build a bed.The truth is, I don't like to do anything."]
# 113 ['Jim_Gaffigan', 87.472, 89.234, "Like when I order delivery, I'm kind of annoyed they don't know what I want already."]
# 114 ['Jim_Gaffigan_2', 11.892, 13.087, "It was a surprise birthday party for a dog. That's right, I have friends that are mentally ill.I went, I went."]
# 115 ['Jim_Gaffigan_2', 17.552, 20.834, 'It was in my apartment building and I needed the material.And to be fair, the dog was surprised.']
# 116 ['Jim_Gaffigan_2', 30.35, 33.624, "Dog didn't know it was his birthday. The dog didn't know it had a birthday."]
# 117 ['Jim_Gaffigan_2', 40.25, 43.14, "The dog wasn't sure why people were in the apartment. It was the dog's third birthday, which in dog years doesn't matter.Someone made that up and we just went along with it."]
# 118 ['Jim_Gaffigan_2', 51.553, 53.033, "Okay. When I see a dog, I'll do math."]
# 119 ['Jim_Gaffigan_2', 60.988, 62.526, 'There\'s not a dog sitting in a bar right now going, "I\'m not three, I\'m 21! I can legally drink!"']
# 120 ['Jim_Gaffigan_2', 86.61, 88.263, 'It\'s a miracle! You\'re back after I don\'t know how long \'cause I\'m a dog."']
# 121 ['Joe_List', 7.456820622986036, 12.396670247046186, 'He knows all three body parts. I was hoping it was three doctors saving money, by sharing a small office.']
# 122 ['Joe_List', 12.84360902255639, 17.148335123523093, 'He\'s like, "I\'m Bill, this is Susan, and Ted. "Ear, nose, throat.']
# 123 ['Joe_List', 25.922448979591834, 27.145649838882917, "It's when you're ears ring, or buzz all the time. I don't know how you say it."]
# 124 ['Joe_List', 45.33114930182599, 53.75026852846401, 'All caps. And then I was like, "Shit, now I don\'t know how to say this word."']
# 125 ['Joe_List', 56.52599355531686, 62.00687432867883, 'This gentlemen is a doctor, he seems very smart. This fella seems, less smart, but, extremely adamant about the pronunciation of this word.']
# 126 ['Joe_List', 78.84940923737915, 87.57647690655209, '"I hear everything, plus ringing, so. "I kind of have superpower hearing, if you think about it.']
# 127 ['Joe_List_2', 11.196, 19.14, "You can be in the second to last row. This one guy behind, you're like what a fucking idiot back there."]
# 128 ['Joe_List_2', 28.809, 35.656, "The whole flight he's like. [yawns] For like five hours."]
# 129 ['Joe_List_2', 36.453, 40.128, '[yawns] I wanted him to die, I swear to God.']
# 130 ['Joe_List_2', 46.263, 47.57, "First of all, you don't need to make a noise when you yawn. That's a decision, he's deciding to do that."]
# 131 ['Joe_List_2', 50.612, 53.391, "It's like, if you were hungry on a plane, you were like, I'm hungry."]
# 132 ['Joe_List_2', 54.398, 59.154, "Well you're all right? Yeah, yeah I'm hungry."]
# 133 ['Joe_List_2', 69.954, 72.391, "of how I came to be tired. Don't fall for it, it's a trap."]
# 156 ['Nate_Bargatze_2', 10.171, 12.779, 'Third grade, you\'re like, "Okay." They throw some stuff in, you\'re like, "Oh, all right.']
# 157 ['Nate_Bargatze_2', 15.292, 19.38, 'All right." It\'s, uh... "Okay, learning it earlier than we used to, huh?"']
# 158 ['Nate_Bargatze_2', 25.393, 27.907, 'Just give it to parents that never learned it. Uh...']
# 159 ['Nate_Bargatze_2', 43.575, 46.371, "If you don't know Common Core, it's just a new math. And the goal of Common Core is to use one sheet of paper for every problem."]
# 160 ['Nate_Bargatze_2', 49.8712, 51.703, 'You... You just want to keep breaking the problem down. You put the problem at the top, and it just keeps going.']
# 161 ['Nate_Bargatze_2', 58.881, 62.509, 'Just do that at the top. I don\'t even know what we\'re doing."']
# 162 ['Nate_Bargatze_2', 67.865, 70.543, 'Old math still... I don\'t get incorrect change everywhere, just going, "This stupid old math!"']
# 163 ['Nate_Bargatze_2', 90.537, 93.376, '"No, it works. I use it, a lot of people still use it, but the new way is to go jump the fence and come in the back and meet me at this same spot."']
# 164 ['Nate_Bargatze_TK', 9.292, 11.846, 'He\'s done that my entire life. He was a clown at the very beginning, just in case you\'re like, "How do you get into something like that?"']
# 165 ['Nate_Bargatze_TK', 16.367, 22.782, "There's two steps. You can take them in either order."]
# 166 ['Nate_Bargatze_TK', 26.02, 27.421, "It was never weird to me. I thought everybody's dad was a clown."]
# 167 ['Nate_Bargatze_TK', 48.091, 50.253, 'And... The Easter Bunny was in the passenger seat.']
# 168 ['Nate_Bargatze_TK', 55.689, 59.162, "That's the first thing that I remember, to my life. If you want to know how you get into comedy, that's a pretty good nudge."]
# 169 ['Nate_Bargatze_TK', 72.16, 74.112, "Like, he couldn't sit normal, so his head was bent to the side. And I remember he had his seat belt on, and he's just like... and I was like..."]
# 170 ['Nate_Bargatze_TK', 80.708, 83.245, 'I like to think about all the other people that saw that. Just in the car next to them, just at a red light, you\'re like, "I didn\'t even know they hung out like that."']
# 171 ['Nate_Bargatze_TK_2', 13.984, 15.303, "It was right outside Louisville, Kentucky, where my parents are from. And my cousin's name is Tuesday, which is a good start."]
# 172 ['Nate_Bargatze_TK_2', 24.249, 28.361, 'The invitation said, "Tuesday\'s getting married, rehearsal\'s Friday, wedding\'s Saturday." People were like, "We gotta be there Monday for this wedding?']
# 173 ['Nate_Bargatze_TK_2', 37.646, 39.765, 'I look like I work there. -Uh... Everybody else just has a football or basketball jersey on.']
# 174 ['Nate_Bargatze_TK_2', 50.124, 51.042, 'No shirt. They forgot his shirt, and instead of waiting to go get it, he was like, "Let\'s do it without it."']
# 175 ['Nate_Bargatze_TK_2', 64.18, 65.875, 'He has a body that you\'re like, "Put your jacket on backwards. Flip it around."']
# 176 ['Nate_Bargatze_TK_2', 70.216, 76.073, 'Then you see his back, and you\'re like, "Oof. All right, go back to regular way.']
# 177 ['Russell_Peters', 10.549, 11.106, "He goes, look, you're a 48-year-old Indian man. I'm like, that's really fucking racist, but since you asked, I have acid reflux."]
# 178 ['Russell_Peters', 17.367, 18.713, "I don't know."]
# 179 ['Russell_Peters', 23.074, 23.734, "Does anybody else- who else has acid reflux in here? First of all, you're lying to me right now."]
# 180 ['Russell_Peters', 38.771, 41.336, "It's inevitable. There's no way you can consume the food that we eat with that much spice, and that much oil, and that much butter, and not just have it burn a hole in your- as my dad would say- your esophagus."]
# 181 ['Russell_Peters', 51.251, 54.234, "No, no, son, esophagus. I don't care whose phagus you think this is."]
# 182 ['Russell_Peters', 70.283, 71.202, "You do, do you. He's like, I know, I have it, but I don't want to say because my shirt looks like turmeric,"]
# 183 ['Russell_Peters_2', 17.69572953736655, 19.65405693950178, "I was like, if I have twin girls- because you've got to have fun with the names. If I have twin girls, these are going to be my daughters, it's going to be Kate and Duplicate."]
# 184 ['Russell_Peters_2', 21.423629893238434, 23.42914590747331, "These are my boys, it's Pete and Repeat."]
# 185 ['Russell_Peters_2', 25.576227758007118, 27.227829181494663, 'If I had twins with a black girl, this is Tyrone and Tyclone.']
# 186 ['Russell_Peters_2', 32.30060498220641, 38.151992882562276, "That's your way of going, look. Look at how good my balls are."]
# 187 ['Russell_Peters_2', 50.0435231316726, 51.12886120996441, "Or because you're Punjabi, look at how good my junk they are. Looks at this.Look at how good my balls are."]
# 188 ['Russell_Peters_2', 55.51740213523132, 57.66448398576512, 'My balls are so strong, they made one kid and then it made the exact same kid right away.']
# 189 ['Russell_Peters_2', 61.36879003558719, 64.76637010676157, 'You lift up your balls, sponsored by Xerox. Sponsored by Xerox.']
# 190 ['Sam_Morril', 9.583, 15.102, "Obviously, it was an accident. No one at the party was like I'm gonna roofie that hairy boy over there."]
# 191 ['Sam_Morril', 21.481, 25.54, 'I just told a room full of people I got roofied. I did not see one concerned face in here.']
# 192 ['Sam_Morril', 28.657, 30.06, 'Everyone in here is like I assume things worked out for you, and they did. Still weird, though.']
# 193 ['Sam_Morril', 43.711, 47.941, "And then I chugged it, and I woke up the next morning, and I was like oh. That guy's a sexual predator."]
# 194 ['Sam_Morril', 51.8923, 53.855, "And my friend said you ruined his night. And I was like, that's not how I want to think about it, you know?"]
# 195 ['Sam_Morril', 56.099, 57.642, "You don't want to think of yourself as a -block to some monster."]
# 196 ['Sam_Morril', 59.629, 64.21, 'I prefer to think of myself as an accidental hero.']
# 197 ['Sam_Morril', 67.623, 68.021, "Statistically, you know... I can't, you guys."]
# 198 ['Sam_Morril', 78.3, 80.526, 'It\'s kind of like if I was driving drunk and I just swerved and accidentally hit a mugger. And some woman is like, "My hero," and I\'m like if you say so, but I might have a substance abuse problem, so...']
# 199 ['Sam_Morril', 107.6833, 109.114, "I was like, yeah, that's a very helpful example. That's always the crossroads I find myself at at 4:57 a.m."]
# 200 ['Sam_Morril', 114.186, 115.612, "I can't tell you how often I'm coming out of a blackout like I should have done doubles instead. That's..."]
# 201 ['Sam_Morril', 123.0456, 124.653, "You tell me to replace an addiction with cardio, that's very helpful. I'm gonna start walking into halfway houses full of crack heads like have you guys done Zumba?"]
# 202 ['Sam_Morril', 128.258, 129.497, "It's so much better than crack."]
# 203 ['Sam_Morril', 135.364, 136.509, "They're like, thanks, we didn't know. That was helpful."]
# 226 ['Trevor_Noah', 37.232, 40.139, "And I know it's stupid to be afraid of the dark, right? Because there's nothing there, nine times out of ten."]
# 227 ['Trevor_Noah', 64.336, 67.965, 'Or do I leave the lights off and shit myself? I never know which one to go with.']
# 228 ['Trevor_Noah', 75.587, 82.391, 'But what I started doing now is I leave the lights off. And when I go the bathroom, I just speak to myself in a Russian accent.']
# 229 ['Trevor_Noah', 84.612, 86.553, 'I feel like I\'m the most dangerous thing in the night. You\'ll find me at three a.m., barefoot, walking to the toilet, like, "Yes.']
# 230 ['Trevor_Noah', 90.69, 95.057, 'Big boy got to make a pee-pee. No trouble over here.']
# 231 ['Trevor_Noah', 101.726, 105.023, 'I feel safe, like even if there\'s a monster under the bed, he\'d be like, "Is that a Russian?" There\'s just something about that Russian accent.']
# 232 ['Trevor_Noah', 174.178, 175.568, 'As soon as he says, "Don\'t be such a bitch!" Just be like... [Russian accent] "You want to see bitch?"']
# 233 ['Trevor_Noah_2', 13.273, 17.662, 'You are destined for greatness. You can\'t be running in the streets: "And a Kit Kat, please."']
# 234 ['Trevor_Noah_2', 26.474, 27.698, '"I\'m not telling you." [laughs] It just doesn\'t work.']
# 235 ['Trevor_Noah_2', 38.852, 40.535, "I remember when Nelson Mandela was still alive, and he would tell jokes at press conferences and events, and no one would laugh. Because everyone thought a man who had been in jail for 27 years couldn't make a joke."]
# 236 ['Trevor_Noah_2', 49.724, 51.042, 'It was partly because of that voice. He would tell the joke, and it would just sound too epic for people to laugh.']
# 237 ['Trevor_Noah_2', 60.423, 62.326, 'Let him in!" "No.']
# 238 ['Trevor_Noah_2', 74.216, 78.397, 'Who are we?\' Oh, my God!"']
# 239 ['Tom_Segura', 22.42, 25.351, 'This dude\'s like, "You trying to get a sack?" -I was like, "Oh, shit.']
# 240 ['Tom_Segura', 31.113, 32.456, 'And he goes, "We just need to go get it." I was like, "You don\'t fuckin\' have it?']
# 241 ['Tom_Segura', 43.95, 46.023, 'You stay here and watch my place." And I was like...']
# 242 ['Tom_Segura', 56.503, 58.176, 'Inside? Paralysis.']
# 243 ['Tom_Segura', 61.4021, 63.451, 'But what I said was, "That\'s what\'s up." -Like, yeah, man.']
# 244 ['Tom_Segura_2', 44.776, 47.44, "-And you hit that. And then you see it close, and you're like..."]
# 245 ['Tom_Segura_2', 50.788, 53.995, 'Sometimes, a second later it opens, and you\'re like, "Fuck!"']
# 246 ['Tom_Segura_2', 58.97, 60.597, 'You get nervous energy, like you\'re a kid. You\'re like, "I\'m in trouble."']

# %%
stand_up_data = pd.DataFrame(list(combined_data.values()), columns=['comedian', 'laugh_start', 'laugh_end', 'sentence'])
print(stand_up_data)
# Out:
#           comedian  laugh_start  laugh_end  \
# 0    Donald_Glover      17.2680     19.352
# 1    Donald_Glover      32.2920     34.182
# 2    Donald_Glover      38.7900     41.441
# 3    Donald_Glover      44.9030     53.441
# 4    Donald_Glover      68.8800     73.824
# ..             ...          ...        ...
# 241     Tom_Segura      56.5030     58.176
# 242     Tom_Segura      61.4021     63.451
# 243   Tom_Segura_2      44.7760     47.440
# 244   Tom_Segura_2      50.7880     53.995
# 245   Tom_Segura_2      58.9700     60.597
#
#                                               sentence
# 0    Just tears, he was giving me this mean mug, he...
# 1    The sweetest thing he was allowed was mints. H...
# 2    So he would steal mints by the handful. So his...
# 3                         Like, he'd be like, "Hello!"
# 4    You know, they were cool. You know, we'd trade...
# ..                                                 ...
# 241                                 Inside? Paralysis.
# 242  But what I said was, "That's what's up." -Like...
# 243  -And you hit that. And then you see it close, ...
# 244  Sometimes, a second later it opens, and you're...
# 245  You get nervous energy, like you're a kid. You...
#
# [246 rows x 4 columns]

# %%
stand_up_data.to_csv('/home/ada/humor/standup_data.csv', index=False)

# %% [markdown]
# Mute all audio but laughter

# %%
# !pip install pydub
# Out:
# Requirement already satisfied: pydub in /home/ada/humor/.venv/lib/python3.8/site-packages (0.25.1)
# [notice] A new release of pip is available: 24.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from pydub import AudioSegment

# %%
def create_silence(duration):
    return AudioSegment.silent(duration=duration)

def create_nonlaughter_audio(input_audio, laugh_times):
    audio = AudioSegment.from_file(input_audio, format="mp3")
    silent_audio = AudioSegment.empty()
    last_end_time = 0
    for laugh in laugh_times.values():
        start = int(laugh['start'] * 1000)
        end = int(laugh['end'] * 1000)
        if start < 0:
            start = 0
        if start > last_end_time:
            silent_audio += create_silence(start - last_end_time)
        laughter_segment = audio[start:end]
        silent_audio += laughter_segment
        last_end_time = end

    if last_end_time < len(audio):
        silent_audio += create_silence(len(audio) - last_end_time)

    return silent_audio

# %%
dg_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/dg/DG_W_audio_11.mp3", dg_laugh_times)

# %%
def plot_muted_audio(muted_audio):
    audio_data = np.array(muted_audio.get_array_of_samples())

    sample_rate = muted_audio.frame_rate
    time_axis = np.linspace(0, len(audio_data) / sample_rate, num=len(audio_data))

    plt.figure(figsize=(14, 5))
    plt.plot(time_axis, audio_data, color='pink')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.title('Muted Audio Waveform')
    plt.grid(True)
    plt.show()

# %%
plot_muted_audio(dg_muted_audio)

# %%
dg_muted_audio.export("/home/ada/humor/data/stand_up_dataset/dg/dg_muted_output.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/dg/dg_muted_output.mp3'>

# %%
aj_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/aj/AJ_TP_audio_15.mp3", aj_laugh_times)

# %%
plot_muted_audio(aj_muted_audio)

# %%
aj_muted_audio.export("/home/ada/humor/data/stand_up_dataset/aj/aj_muted_output.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/aj/aj_muted_output.mp3'>

# %%
cp_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/cp/CP_OTG_audio_18.mp3", cp_laugh_times)

# %%
plot_muted_audio(cp_muted_audio)

# %%
cp_muted_audio.export("/home/ada/humor/data/stand_up_dataset/cp/cp_muted_output.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/cp/cp_muted_output.mp3'>

# %%
lck_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/lck/LCK_SY_audio_06.mp3", lck_laugh_times)
plot_muted_audio(lck_muted_audio)
lck_muted_audio.export("/home/ada/humor/data/stand_up_dataset/lck/lck_muted_output.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/lck/lck_muted_output.mp3'>

# %%
jm_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/jm/JM_KDRC_audio_12.mp3", jm_laugh_times)
plot_muted_audio(jm_muted_audio)
jm_muted_audio.export("/home/ada/humor/data/stand_up_dataset/jm/jm_muted_output.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/jm/jm_muted_output.mp3'>

# %%
aj2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/aj2/AJ_TP_audio_25.mp3", aj2_laugh_times)
plot_muted_audio(aj2_muted_audio)
aj2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/aj2/AJ2_TP_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/aj2/AJ2_TP_muted_audio.mp3'>

# %%
aj2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/aj2/AJ_TP_audio_25.mp3", aj2_laugh_times)
plot_muted_audio(aj2_muted_audio)
aj2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/aj2/AJ2_TP_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/aj2/AJ2_TP_muted_audio.mp3'>

# %%
import numpy as np

# %%
aw_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/aw/AW_BC_audio_04.mp3", aw_laugh_times)
plot_muted_audio(aw_muted_audio)
aw_muted_audio.export("/home/ada/humor/data/stand_up_dataset/aw/aw_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/aw/aw_muted_audio.mp3'>

# %%
aw2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/aw2/AW_BC_audio_25.mp3", aw2_laugh_times)
plot_muted_audio(aw2_muted_audio)
aw2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/aw2/aw2_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/aw2/aw2_muted_audio.mp3'>

# %%
cp2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/cp2/CP_OTG_audio_07.mp3", cp2_laugh_times)
plot_muted_audio(cp2_muted_audio)
cp2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/cp2/cp2_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/cp2/cp2_muted_audio.mp3'>

# %%
dg2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/dg2/DG_W_audio_07.mp3", dg2_laugh_times)
plot_muted_audio(dg2_muted_audio)
dg2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/dg2/dg2_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/dg2/dg2_muted_audio.mp3'>

# %%
hm_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/hm/HM_HK_audio_05.mp3", hm_laugh_times)
plot_muted_audio(hm_muted_audio)
hm_muted_audio.export("/home/ada/humor/data/stand_up_dataset/hm/hm_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/hm/hm_muted_audio.mp3'>

# %%
hm2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/hm2/HM_HK_audio_22.mp3", hm2_laugh_times)
plot_muted_audio(hm2_muted_audio)
hm2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/hm2/hm2_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/hm2/hm2_muted_audio.mp3'>

# %%
is_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/is/IS_EM_audio_18.mp3", is_laugh_times)
plot_muted_audio(is_muted_audio)
is_muted_audio.export("/home/ada/humor/data/stand_up_dataset/is/is_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/is/is_muted_audio.mp3'>

# %%
is2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/is2/IS_EM_audio_20.mp3", is2_laugh_times)
plot_muted_audio(is2_muted_audio)
is2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/is2/is2_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/is2/is2_muted_audio.mp3'>

# %%
jg_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/jg/JG_QT_audio_03.mp3", jg_laugh_times)
plot_muted_audio(jg_muted_audio)
jg_muted_audio.export("/home/ada/humor/data/stand_up_dataset/jg/jg_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/jg/jg_muted_audio.mp3'>

# %%
jg2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/jg2/JG_QT_audio_14.mp3", jg2_laugh_times)
plot_muted_audio(jg2_muted_audio)
jg2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/jg2/jg2_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/jg2/jg2_muted_audio.mp3'>

# %%
jl_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/ji/JL_IHM_audio_11.mp3", jl_laugh_times)
plot_muted_audio(jl_muted_audio)
jl_muted_audio.export("/home/ada/humor/data/stand_up_dataset/ji/jl_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/ji/jl_muted_audio.mp3'>

# %%
jl2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/ji2/JL_IHM_audio_02.mp3", jl2_laugh_times)
plot_muted_audio(jl2_muted_audio)
jl2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/ji2/jl2_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/ji2/jl2_muted_audio.mp3'>

# %%
jm2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/jm2/JM_KDRC_audio_06.mp3", jm2_laugh_times)
plot_muted_audio(jm2_muted_audio)
jm2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/jm2/jm2_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/jm2/jm2_muted_audio.mp3'>

# %%
jy_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/jy/JY_GD_audio_09.mp3", jy_laugh_times)
plot_muted_audio(jy_muted_audio)
jy_muted_audio.export("/home/ada/humor/data/stand_up_dataset/jy/jy_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/jy/jy_muted_audio.mp3'>

# %%
jy2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/jy2/JY_GD_audio_19.mp3", jy2_laugh_times)
plot_muted_audio(jy2_muted_audio)
jy2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/jy2/jy2_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/jy2/jy2_muted_audio.mp3'>

# %%
lck2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/lck2/LCK_SY_audio_20.mp3", lck2_laugh_times)
plot_muted_audio(lck2_muted_audio)
lck2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/lck2/lck2_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/lck2/lck2_muted_audio.mp3'>

# %%
nb_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/nb/NB_TGAA_audio_09.mp3", nb_laugh_times)
plot_muted_audio(nb_muted_audio)
nb_muted_audio.export("/home/ada/humor/data/stand_up_dataset/nb/nb_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/nb/nb_muted_audio.mp3'>

# %%
nb_tk_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/nb_tk/NB_TK_audio_20.mp3", nb_tk_laugh_times)
plot_muted_audio(nb_tk_muted_audio)
nb_tk_muted_audio.export("/home/ada/humor/data/stand_up_dataset/nb_tk/nb_tk_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/nb_tk/nb_tk_muted_audio.mp3'>

# %%
nb_tk2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/nb_tk2/NB_TK_audio_17.mp3", nb_tk2_laugh_times)
plot_muted_audio(nb_tk2_muted_audio)
nb_tk2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/nb_tk2/nb_tk2_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/nb_tk2/nb_tk2_muted_audio.mp3'>

# %%
nb2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/nb2/NB_TGAA_audio_14.mp3", nb2_laugh_times)
plot_muted_audio(nb2_muted_audio)
nb2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/nb2/nb2_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/nb2/nb2_muted_audio.mp3'>

# %%
rp_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/rp/RP_DP_audio_06.mp3", rp_laugh_times)
plot_muted_audio(rp_muted_audio)
rp_muted_audio.export("/home/ada/humor/data/stand_up_dataset/rp/rp_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/rp/rp_muted_audio.mp3'>

# %%
rp2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/rp2/RP_DP_audio_21.mp3", rp2_laugh_times)
plot_muted_audio(rp2_muted_audio)
rp2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/rp2/rp2_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/rp2/rp2_muted_audio.mp3'>

# %%
sm_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/sm/SM_IGT_audio_04.mp3", sm_laugh_times)
plot_muted_audio(sm_muted_audio)
sm_muted_audio.export("/home/ada/humor/data/stand_up_dataset/sm/sm_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/sm/sm_muted_audio.mp3'>

# %%
sm2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/sm2/SM_IGT_audio_13.mp3", sm2_laugh_times)
plot_muted_audio(sm2_muted_audio)
sm2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/sm2/sm2_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/sm2/sm2_muted_audio.mp3'>

# %%
tn_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/tn/TN_AD_audio_16.mp3", tn_laugh_times)
plot_muted_audio(tn_muted_audio)
tn_muted_audio.export("/home/ada/humor/data/stand_up_dataset/tn/tn_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/tn/tn_muted_audio.mp3'>

# %%
tn2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/tn2/TN_AD_audio_14.mp3", tn2_laugh_times)
plot_muted_audio(tn2_muted_audio)
tn2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/tn2/tn2_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/tn2/tn2_muted_audio.mp3'>

# %%
ts_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/ts/TS_D_audio_09.mp3", ts_laugh_times)
plot_muted_audio(ts_muted_audio)
ts_muted_audio.export("/home/ada/humor/data/stand_up_dataset/ts/ts_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/ts/ts_muted_audio.mp3'>

# %%
ts2_muted_audio = create_nonlaughter_audio("/home/ada/humor/data/stand_up_dataset/ts2/TS_D_audio_15.mp3", ts2_laugh_times)
plot_muted_audio(ts2_muted_audio)
ts2_muted_audio.export("/home/ada/humor/data/stand_up_dataset/ts2/ts2_muted_audio.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/home/ada/humor/data/stand_up_dataset/ts2/ts2_muted_audio.mp3'>
